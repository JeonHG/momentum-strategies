# %% [markdown]
# ### simple simulation - no transaction fee, no etf expenses, no taxes, no dividends

# %% [markdown]
# # 초기 조건 / 데이터 임포트 / 벤치마크 계산

# %% [markdown]
# ## 라이브러리 임포트 / 초기 조건 설정

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import math

# %%
transaction_fee = 0.0025
etf_expenses = 0.0009
tax_rate = 0.22
initial_cash = 10000

# %%
current_date = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")

# %%
strategies = []
returns = []

# %% [markdown]
# ## 데이터 임포트

# %%
df = pd.read_csv('/content/drive/MyDrive/quant_projects/momentum_strategies/SPY.csv')[:-2] # 2021-09까지 결과 출력
closes = df.Close.to_numpy()
opens = df.Open.to_numpy()

# %%
tb3_df = pd.read_csv('/content/drive/MyDrive/quant_projects/momentum_strategies/TB3MS.csv')
risk_free_rates = tb3_df.TB3MS.to_numpy() / 100

# %% [markdown]
# ## 벤치마크 계산

# %%
benchmark_shares = initial_cash // closes[0]
benchmark = closes * benchmark_shares

# %%
# 출처: http://blog.quantylab.com/mdd.html
def get_mdd(x):
    """
    MDD(Maximum Draw-Down)
    :return: (peak_upper, peak_lower, mdd rate)
    """
    arr_v = np.array(x)
    peak_lower = np.argmax(np.maximum.accumulate(arr_v) - arr_v)
    peak_upper = np.argmax(arr_v[:peak_lower])
    return peak_upper, peak_lower, (arr_v[peak_lower] - arr_v[peak_upper]) / arr_v[peak_upper]

# %%
# highs = df.High.to_numpy()
# lows = df.Low.to_numpy()

# %%
# np.argmax(np.maximum.accumulate(highs))

# %%
# 월중 mdd 
# max((np.maximum.accumulate(highs) - lows) / np.maximum.accumulate(highs))

# %%
# 월중 mdd
# peak_lower = np.argmax((np.maximum.accumulate(highs) - lows) / np.maximum.accumulate(highs))
# peak_upper = np.argmax(highs[:peak_lower])
# print(peak_upper, peak_lower, (lows[peak_lower] - highs[peak_upper]) / highs[peak_upper])

# %%
# get_mdd(benchmark)

# %%
def annualize(closes, opens, month_lag):
  annual_returns = []
  for i in range(len(closes) // 12 +1):
    if (i+1)*12 > len(closes):
      annual_returns.append(round((closes[-1] - opens[i*12-month_lag]) / opens[i*12-month_lag],4))
    elif i*12-month_lag < 0:
      annual_returns.append(round((closes[i*12+11-month_lag] - opens[0]) / opens[0], 4))
    else:
      annual_returns.append(round((closes[i*12+11-month_lag] - opens[i*12-month_lag]) / opens[i*12-month_lag],4))
  return annual_returns

# %%
def statistics(name, closes, annual_returns, current_flag=False):
  mean_risk_free_rate = np.mean(risk_free_rates) if current_flag else 0.005
  cagr = round(pow(closes[-1] / closes[0], 1/ (round(len(closes) / 12))) - 1, 4)
  mean_annual = round(np.mean(annual_returns),4)
  stddev = round(np.std(annual_returns),4)
  sharpe = round((np.mean(annual_returns)- mean_risk_free_rate) / np.std(annual_returns),4)
  worst_year = round(min(annual_returns), 4)
  best_year = round(max(annual_returns), 4)
  mdd = round(get_mdd(closes)[2], 4)
  return {'name':name, 'initial_balance': round(closes[0], 2), 'final_balance':round(closes[-1],2), 'cagr':cagr, 'mean_annual':mean_annual, 'stddev':stddev, 'sharpe':sharpe, 'worst_year':worst_year, 'best_year': best_year, 'mdd': mdd}

# %%
strategies.append(statistics('Benchmark', benchmark, annualize(closes, opens, 1)))
returns.append({"name":'Benchmark', "df":benchmark})

# %%
strategies
# Out:
# [{'best_year': 0.3453,
#   'cagr': 0.0814,
#   'final_balance': 96556.5,
#   'initial_balance': 9991.41,
#   'mdd': -0.522,
#   'mean_annual': 0.0922,
#   'name': 'Benchmark',
#   'sharpe': 0.5243,
#   'stddev': 0.1664,
#   'worst_year': -0.3842}]

# %% [markdown]
# # Simulation

# %%
start_lag = 2 # data starts from 1993-02
rebalancing_periods = [1,2,3,4,6,12]
look_backs = [1,2,3,4,6,12]
for rebalancing_period in rebalancing_periods:
  for look_back in look_backs:
    for index in range(rebalancing_period):
      # 2개월 리밸런싱 -> 홀수달/짝수달, 3개월 리밸런싱 -> 0/1/2, 4개월 리밸런싱 -> 0/1/2/3
      for exclude_period in range(min(3, look_back)):
        df_temp = pd.DataFrame({'Date': df['Date'], 'Close': df['Close'], 'Open': df['Open']})
        simulation_detail = f'{index + start_lag}to{index + start_lag + rebalancing_period}ex{exclude_period}'
        name = f'SPY_simulation_{rebalancing_period}:{look_back}_{simulation_detail}'
        cash, month_closes, month_opens = [np.array([initial_cash] * len(closes), dtype=np.float64) for _ in range(3)]
        upwards, positions, shares = [np.zeros(len(closes)) for _ in range(3)]
        for i in range(12, len(closes)):
          # 12개월까지는 모든 포트폴리오가 현금보유, 벤치마크는 0개월부터 투자시작
          #조건에 만족하면 배당수익 기록 (보유 현금 증가로)
          # cash[i] = cash[i - rebalancing_period] dividends[i] * shares[i - rebalancing_period]
          if i % rebalancing_period == index:
            upwards[i] = 1 if (closes[i-exclude_period] - closes[i-look_back]) / closes[i-look_back] >= risk_free_rates[i] else 0
            shares[i] = (shares[i - 1] * closes[i] + cash[i - 1]) * upwards[i] // closes[i]
            shares_delta = shares[i] - shares[i - 1]
            month_opens[i] = cash[i-1] + shares[i-1] * opens[i]
            if shares_delta == 0:
              # 보유
              cash[i] = cash[i - 1] #만약 지난달에 배당을 받았다면 주식:현금 비율이 변화하므로 리밸런싱 필요
              positions[i] = shares[i] * closes[i]
            else:
              # 추가 매수, 매도 공통
              cash[i] = cash[i - 1] - (shares_delta) * closes[i] #shares_delta가 양수면 매수, 음수면 매도
              positions[i] = closes[i] * shares[i]
              # 거래비용 기록
              if shares_delta < 0:
                # 매도로 인한 손익 기록
                pass
          else:
            month_opens[i] = cash[i-1] + shares[i-1] * opens[i]
            cash[i] = cash[i-1]
            shares[i] = shares[i-1]
            positions[i] = shares[i] * closes[i]
          month_closes[i] = cash[i] + positions[i]
        df_temp['Upward'] = upwards.tolist()
        df_temp['Shares'] = shares.tolist()
        df_temp['Position'] = positions.tolist()
        df_temp['Cash'] = cash.tolist()
        df_temp['Month_close'] = month_closes.tolist()
        df_temp['Month_open'] = month_opens.tolist()
        df_temp['Benchmark'] = benchmark.tolist()
        # df_temp.to_csv(f'/content/drive/MyDrive/quant_projects/momentum_strategies/{current_date}_{name}.csv')
        strategies.append(statistics(name, month_closes, annualize(month_closes, month_opens, 1)))
        returns.append({"name":name, "df":df_temp['Month_close'].to_numpy()})

# %%
strategies
# Out:
# [{'best_year': 0.3453,
#   'cagr': 0.0814,
#   'final_balance': 96556.5,
#   'initial_balance': 9991.41,
#   'mdd': -0.522,
#   'mean_annual': 0.0922,
#   'name': 'Benchmark',
#   'sharpe': 0.5243,
#   'stddev': 0.1664,
#   'worst_year': -0.3842},
#  {'best_year': 0.2664,
#   'cagr': 0.0351,
#   'final_balance': 27171.36,
#   'initial_balance': 10000.0,
#   'mdd': -0.2023,
#   'mean_annual': 0.0358,
#   'name': 'SPY_simulation_1:1_2to3ex0',
#   'sharpe': 0.344,
#   'stddev': 0.0895,
#   'worst_year': -0.1429},
#  {'best_year': 0.273,
#   'cagr': 0.0421,
#   'final_balance': 33079.01,
#   'initial_balance': 10000.0,
#   'mdd': -0.1165,
#   'mean_annual': 0.0429,
#   'name': 'SPY_simulation_1:2_2to3ex0',
#   'sharpe': 0.422,
#   'stddev': 0.0899,
#   'worst_year': -0.0913},
#  {'best_year': 0.2519,
#   'cagr': 0.0284,
#   'final_balance': 22496.02,
#   'initial_balance': 10000.0,
#   'mdd': -0.3392,
#   'mean_annual': 0.0301,
#   'name': 'SPY_simulation_1:2_2to3ex1',
#   'sharpe': 0.2758,
#   'stddev': 0.0912,
#   'worst_year': -0.2372},
#  {'best_year': 0.2736,
#   'cagr': 0.0536,
#   'final_balance': 45497.96,
#   'initial_balance': 10000.0,
#   'mdd': -0.1795,
#   'mean_annual': 0.0557,
#   'name': 'SPY_simulation_1:3_2to3ex0',
#   'sharpe': 0.4905,
#   'stddev': 0.1034,
#   'worst_year': -0.1334},
#  {'best_year': 0.2031,
#   'cagr': 0.0456,
#   'final_balance': 36480.14,
#   'initial_balance': 10000.0,
#   'mdd': -0.1989,
#   'mean_annual': 0.0464,
#   'name': 'SPY_simulation_1:3_2to3ex1',
#   'sharpe': 0.4688,
#   'stddev': 0.0883,
#   'worst_year': -0.0956},
#  {'best_year': 0.1673,
#   'cagr': 0.0242,
#   'final_balance': 20011.13,
#   'initial_balance': 10000.0,
#   'mdd': -0.2352,
#   'mean_annual': 0.0252,
#   'name': 'SPY_simulation_1:3_2to3ex2',
#   'sharpe': 0.2917,
#   'stddev': 0.0691,
#   'worst_year': -0.1131},
#  {'best_year': 0.2709,
#   'cagr': 0.0503,
#   'final_balance': 41496.11,
#   'initial_balance': 10000.0,
#   'mdd': -0.2574,
#   'mean_annual': 0.0522,
#   'name': 'SPY_simulation_1:4_2to3ex0',
#   'sharpe': 0.4521,
#   'stddev': 0.1045,
#   'worst_year': -0.1194},
#  {'best_year': 0.255,
#   'cagr': 0.0477,
#   'final_balance': 38648.64,
#   'initial_balance': 10000.0,
#   'mdd': -0.2442,
#   'mean_annual': 0.0477,
#   'name': 'SPY_simulation_1:4_2to3ex1',
#   'sharpe': 0.4983,
#   'stddev': 0.0856,
#   'worst_year': -0.0767},
#  {'best_year': 0.2313,
#   'cagr': 0.0396,
#   'final_balance': 30801.91,
#   'initial_balance': 10000.0,
#   'mdd': -0.291,
#   'mean_annual': 0.0406,
#   'name': 'SPY_simulation_1:4_2to3ex2',
#   'sharpe': 0.4261,
#   'stddev': 0.0835,
#   'worst_year': -0.1009},
#  {'best_year': 0.3128,
#   'cagr': 0.0621,
#   'final_balance': 57350.43,
#   'initial_balance': 10000.0,
#   'mdd': -0.1457,
#   'mean_annual': 0.0648,
#   'name': 'SPY_simulation_1:6_2to3ex0',
#   'sharpe': 0.5174,
#   'stddev': 0.1155,
#   'worst_year': -0.1567},
#  {'best_year': 0.3039,
#   'cagr': 0.0494,
#   'final_balance': 40505.46,
#   'initial_balance': 10000.0,
#   'mdd': -0.2775,
#   'mean_annual': 0.0522,
#   'name': 'SPY_simulation_1:6_2to3ex1',
#   'sharpe': 0.4425,
#   'stddev': 0.1067,
#   'worst_year': -0.147},
#  {'best_year': 0.2713,
#   'cagr': 0.0585,
#   'final_balance': 52070.21,
#   'initial_balance': 10000.0,
#   'mdd': -0.2885,
#   'mean_annual': 0.0608,
#   'name': 'SPY_simulation_1:6_2to3ex2',
#   'sharpe': 0.5804,
#   'stddev': 0.0962,
#   'worst_year': -0.1297},
#  {'best_year': 0.3049,
#   'cagr': 0.0745,
#   'final_balance': 80398.5,
#   'initial_balance': 10000.0,
#   'mdd': -0.2635,
#   'mean_annual': 0.0768,
#   'name': 'SPY_simulation_1:12_2to3ex0',
#   'sharpe': 0.6502,
#   'stddev': 0.1104,
#   'worst_year': -0.1069},
#  {'best_year': 0.3048,
#   'cagr': 0.0847,
#   'final_balance': 105669.3,
#   'initial_balance': 10000.0,
#   'mdd': -0.1991,
#   'mean_annual': 0.0868,
#   'name': 'SPY_simulation_1:12_2to3ex1',
#   'sharpe': 0.8423,
#   'stddev': 0.0971,
#   'worst_year': -0.0623},
#  {'best_year': 0.3043,
#   'cagr': 0.0755,
#   'final_balance': 82569.43,
#   'initial_balance': 10000.0,
#   'mdd': -0.2135,
#   'mean_annual': 0.0783,
#   'name': 'SPY_simulation_1:12_2to3ex2',
#   'sharpe': 0.6829,
#   'stddev': 0.1073,
#   'worst_year': -0.0991},
#  {'best_year': 0.1868,
#   'cagr': 0.0275,
#   'final_balance': 21954.46,
#   'initial_balance': 10000.0,
#   'mdd': -0.3014,
#   'mean_annual': 0.0279,
#   'name': 'SPY_simulation_2:1_2to4ex0',
#   'sharpe': 0.2714,
#   'stddev': 0.0844,
#   'worst_year': -0.1304},
#  {'best_year': 0.3994,
#   'cagr': 0.0415,
#   'final_balance': 32515.18,
#   'initial_balance': 10000.0,
#   'mdd': -0.199,
#   'mean_annual': 0.0443,
#   'name': 'SPY_simulation_2:1_3to5ex0',
#   'sharpe': 0.3633,
#   'stddev': 0.1082,
#   'worst_year': -0.1422},
#  {'best_year': 0.3043,
#   'cagr': 0.056,
#   'final_balance': 48539.77,
#   'initial_balance': 10000.0,
#   'mdd': -0.0791,
#   'mean_annual': 0.0576,
#   'name': 'SPY_simulation_2:2_2to4ex0',
#   'sharpe': 0.5199,
#   'stddev': 0.1011,
#   'worst_year': -0.0742},
#  {'best_year': 0.2739,
#   'cagr': 0.0363,
#   'final_balance': 28123.04,
#   'initial_balance': 10000.0,
#   'mdd': -0.0954,
#   'mean_annual': 0.037,
#   'name': 'SPY_simulation_2:2_2to4ex1',
#   'sharpe': 0.3855,
#   'stddev': 0.0831,
#   'worst_year': -0.1139},
#  {'best_year': 0.2029,
#   'cagr': 0.0345,
#   'final_balance': 26721.29,
#   'initial_balance': 10000.0,
#   'mdd': -0.2426,
#   'mean_annual': 0.0347,
#   'name': 'SPY_simulation_2:2_3to5ex0',
#   'sharpe': 0.3671,
#   'stddev': 0.0809,
#   'worst_year': -0.1054},
#  {'best_year': 0.1564,
#   'cagr': 0.0194,
#   'final_balance': 17473.64,
#   'initial_balance': 10000.0,
#   'mdd': -0.4042,
#   'mean_annual': 0.022,
#   'name': 'SPY_simulation_2:2_3to5ex1',
#   'sharpe': 0.1997,
#   'stddev': 0.0853,
#   'worst_year': -0.2958},
#  {'best_year': 0.2747,
#   'cagr': 0.0496,
#   'final_balance': 40704.47,
#   'initial_balance': 10000.0,
#   'mdd': -0.1283,
#   'mean_annual': 0.0506,
#   'name': 'SPY_simulation_2:3_2to4ex0',
#   'sharpe': 0.4977,
#   'stddev': 0.0916,
#   'worst_year': -0.1295},
#  {'best_year': 0.2119,
#   'cagr': 0.0314,
#   'final_balance': 24493.91,
#   'initial_balance': 10000.0,
#   'mdd': -0.2863,
#   'mean_annual': 0.0315,
#   'name': 'SPY_simulation_2:3_2to4ex1',
#   'sharpe': 0.334,
#   'stddev': 0.0792,
#   'worst_year': -0.0897},
#  {'best_year': 0.198,
#   'cagr': 0.0176,
#   'final_balance': 16586.69,
#   'initial_balance': 10000.0,
#   'mdd': -0.2611,
#   'mean_annual': 0.0186,
#   'name': 'SPY_simulation_2:3_2to4ex2',
#   'sharpe': 0.1964,
#   'stddev': 0.0692,
#   'worst_year': -0.1485},
#  {'best_year': 0.2719,
#   'cagr': 0.0538,
#   'final_balance': 45733.27,
#   'initial_balance': 10000.0,
#   'mdd': -0.2677,
#   'mean_annual': 0.055,
#   'name': 'SPY_simulation_2:3_3to5ex0',
#   'sharpe': 0.502,
#   'stddev': 0.0996,
#   'worst_year': -0.1235},
#  {'best_year': 0.2717,
#   'cagr': 0.054,
#   'final_balance': 46021.38,
#   'initial_balance': 10000.0,
#   'mdd': -0.198,
#   'mean_annual': 0.0563,
#   'name': 'SPY_simulation_2:3_3to5ex1',
#   'sharpe': 0.5256,
#   'stddev': 0.0975,
#   'worst_year': -0.1523},
#  {'best_year': 0.2721,
#   'cagr': 0.0351,
#   'final_balance': 27174.29,
#   'initial_balance': 10000.0,
#   'mdd': -0.2646,
#   'mean_annual': 0.0371,
#   'name': 'SPY_simulation_2:3_3to5ex2',
#   'sharpe': 0.3668,
#   'stddev': 0.0875,
#   'worst_year': -0.1391},
#  {'best_year': 0.2721,
#   'cagr': 0.0622,
#   'final_balance': 57529.92,
#   'initial_balance': 10000.0,
#   'mdd': -0.1357,
#   'mean_annual': 0.0634,
#   'name': 'SPY_simulation_2:4_2to4ex0',
#   'sharpe': 0.5919,
#   'stddev': 0.0988,
#   'worst_year': -0.0793},
#  {'best_year': 0.2723,
#   'cagr': 0.0538,
#   'final_balance': 45714.88,
#   'initial_balance': 10000.0,
#   'mdd': -0.3546,
#   'mean_annual': 0.0547,
#   'name': 'SPY_simulation_2:4_2to4ex1',
#   'sharpe': 0.5158,
#   'stddev': 0.0964,
#   'worst_year': -0.1495},
#  {'best_year': 0.2709,
#   'cagr': 0.0383,
#   'final_balance': 29778.11,
#   'initial_balance': 10000.0,
#   'mdd': -0.3395,
#   'mean_annual': 0.0402,
#   'name': 'SPY_simulation_2:4_2to4ex2',
#   'sharpe': 0.3773,
#   'stddev': 0.0932,
#   'worst_year': -0.1275},
#  {'best_year': 0.2726,
#   'cagr': 0.0405,
#   'final_balance': 31626.36,
#   'initial_balance': 10000.0,
#   'mdd': -0.2265,
#   'mean_annual': 0.0424,
#   'name': 'SPY_simulation_2:4_3to5ex0',
#   'sharpe': 0.3713,
#   'stddev': 0.1006,
#   'worst_year': -0.1389},
#  {'best_year': 0.2158,
#   'cagr': 0.0433,
#   'final_balance': 34187.69,
#   'initial_balance': 10000.0,
#   'mdd': -0.1986,
#   'mean_annual': 0.0447,
#   'name': 'SPY_simulation_2:4_3to5ex1',
#   'sharpe': 0.4461,
#   'stddev': 0.0889,
#   'worst_year': -0.1379},
#  {'best_year': 0.2543,
#   'cagr': 0.0361,
#   'final_balance': 27981.37,
#   'initial_balance': 10000.0,
#   'mdd': -0.1988,
#   'mean_annual': 0.0393,
#   'name': 'SPY_simulation_2:4_3to5ex2',
#   'sharpe': 0.3538,
#   'stddev': 0.0969,
#   'worst_year': -0.1424},
#  {'best_year': 0.3045,
#   'cagr': 0.0517,
#   'final_balance': 43151.93,
#   'initial_balance': 10000.0,
#   'mdd': -0.2235,
#   'mean_annual': 0.0543,
#   'name': 'SPY_simulation_2:6_2to4ex0',
#   'sharpe': 0.4366,
#   'stddev': 0.1129,
#   'worst_year': -0.1286},
#  {'best_year': 0.3038,
#   'cagr': 0.051,
#   'final_balance': 42316.0,
#   'initial_balance': 10000.0,
#   'mdd': -0.3146,
#   'mean_annual': 0.0535,
#   'name': 'SPY_simulation_2:6_2to4ex1',
#   'sharpe': 0.4708,
#   'stddev': 0.103,
#   'worst_year': -0.128},
#  {'best_year': 0.3036,
#   'cagr': 0.0575,
#   'final_balance': 50643.02,
#   'initial_balance': 10000.0,
#   'mdd': -0.2644,
#   'mean_annual': 0.06,
#   'name': 'SPY_simulation_2:6_2to4ex2',
#   'sharpe': 0.557,
#   'stddev': 0.0987,
#   'worst_year': -0.0825},
#  {'best_year': 0.3122,
#   'cagr': 0.0629,
#   'final_balance': 58679.54,
#   'initial_balance': 10000.0,
#   'mdd': -0.1987,
#   'mean_annual': 0.0658,
#   'name': 'SPY_simulation_2:6_3to5ex0',
#   'sharpe': 0.5186,
#   'stddev': 0.1173,
#   'worst_year': -0.1069},
#  {'best_year': 0.3035,
#   'cagr': 0.0521,
#   'final_balance': 43617.97,
#   'initial_balance': 10000.0,
#   'mdd': -0.2186,
#   'mean_annual': 0.0551,
#   'name': 'SPY_simulation_2:6_3to5ex1',
#   'sharpe': 0.4393,
#   'stddev': 0.1141,
#   'worst_year': -0.1109},
#  {'best_year': 0.2852,
#   'cagr': 0.055,
#   'final_balance': 47282.48,
#   'initial_balance': 10000.0,
#   'mdd': -0.1987,
#   'mean_annual': 0.0586,
#   'name': 'SPY_simulation_2:6_3to5ex2',
#   'sharpe': 0.5078,
#   'stddev': 0.1056,
#   'worst_year': -0.13},
#  {'best_year': 0.3042,
#   'cagr': 0.0816,
#   'final_balance': 97287.05,
#   'initial_balance': 10000.0,
#   'mdd': -0.2328,
#   'mean_annual': 0.0832,
#   'name': 'SPY_simulation_2:12_2to4ex0',
#   'sharpe': 0.7538,
#   'stddev': 0.1037,
#   'worst_year': -0.0865},
#  {'best_year': 0.3042,
#   'cagr': 0.0799,
#   'final_balance': 92954.14,
#   'initial_balance': 10000.0,
#   'mdd': -0.199,
#   'mean_annual': 0.0832,
#   'name': 'SPY_simulation_2:12_2to4ex1',
#   'sharpe': 0.7164,
#   'stddev': 0.1092,
#   'worst_year': -0.0866},
#  {'best_year': 0.3049,
#   'cagr': 0.0695,
#   'final_balance': 70161.89,
#   'initial_balance': 10000.0,
#   'mdd': -0.2731,
#   'mean_annual': 0.0723,
#   'name': 'SPY_simulation_2:12_2to4ex2',
#   'sharpe': 0.6265,
#   'stddev': 0.1074,
#   'worst_year': -0.1158},
#  {'best_year': 0.3045,
#   'cagr': 0.0704,
#   'final_balance': 71961.31,
#   'initial_balance': 10000.0,
#   'mdd': -0.2157,
#   'mean_annual': 0.0737,
#   'name': 'SPY_simulation_2:12_3to5ex0',
#   'sharpe': 0.5929,
#   'stddev': 0.1158,
#   'worst_year': -0.1076},
#  {'best_year': 0.305,
#   'cagr': 0.0793,
#   'final_balance': 91410.89,
#   'initial_balance': 10000.0,
#   'mdd': -0.1992,
#   'mean_annual': 0.0802,
#   'name': 'SPY_simulation_2:12_3to5ex1',
#   'sharpe': 0.774,
#   'stddev': 0.0972,
#   'worst_year': -0.1074},
#  {'best_year': 0.3044,
#   'cagr': 0.0839,
#   'final_balance': 103467.49,
#   'initial_balance': 10000.0,
#   'mdd': -0.1987,
#   'mean_annual': 0.0863,
#   'name': 'SPY_simulation_2:12_3to5ex2',
#   'sharpe': 0.7515,
#   'stddev': 0.1082,
#   'worst_year': -0.1076},
#  {'best_year': 0.2042,
#   'cagr': 0.0315,
#   'final_balance': 24598.08,
#   'initial_balance': 10000.0,
#   'mdd': -0.2576,
#   'mean_annual': 0.0319,
#   'name': 'SPY_simulation_3:1_2to5ex0',
#   'sharpe': 0.3554,
#   'stddev': 0.0757,
#   'worst_year': -0.13},
#  {'best_year': 0.2145,
#   'cagr': 0.0235,
#   'final_balance': 19614.05,
#   'initial_balance': 10000.0,
#   'mdd': -0.3614,
#   'mean_annual': 0.0233,
#   'name': 'SPY_simulation_3:1_3to6ex0',
#   'sharpe': 0.2382,
#   'stddev': 0.0768,
#   'worst_year': -0.1354},
#  {'best_year': 0.2327,
#   'cagr': 0.0448,
#   'final_balance': 35597.22,
#   'initial_balance': 10000.0,
#   'mdd': -0.1147,
#   'mean_annual': 0.0469,
#   'name': 'SPY_simulation_3:1_4to7ex0',
#   'sharpe': 0.481,
#   'stddev': 0.0871,
#   'worst_year': -0.0824},
#  {'best_year': 0.2177,
#   'cagr': 0.0458,
#   'final_balance': 36651.04,
#   'initial_balance': 10000.0,
#   'mdd': -0.2526,
#   'mean_annual': 0.0473,
#   'name': 'SPY_simulation_3:2_2to5ex0',
#   'sharpe': 0.4358,
#   'stddev': 0.0971,
#   'worst_year': -0.0931},
#  {'best_year': 0.2167,
#   'cagr': 0.0327,
#   'final_balance': 25453.54,
#   'initial_balance': 10000.0,
#   'mdd': -0.233,
#   'mean_annual': 0.0345,
#   'name': 'SPY_simulation_3:2_2to5ex1',
#   'sharpe': 0.3633,
#   'stddev': 0.0811,
#   'worst_year': -0.0933},
#  {'best_year': 0.2116,
#   'cagr': 0.0412,
#   'final_balance': 32287.66,
#   'initial_balance': 10000.0,
#   'mdd': -0.2838,
#   'mean_annual': 0.041,
#   'name': 'SPY_simulation_3:2_3to6ex0',
#   'sharpe': 0.472,
#   'stddev': 0.0763,
#   'worst_year': -0.0944},
#  {'best_year': 0.2103,
#   'cagr': 0.0151,
#   'final_balance': 15449.28,
#   'initial_balance': 10000.0,
#   'mdd': -0.285,
#   'mean_annual': 0.0164,
#   'name': 'SPY_simulation_3:2_3to6ex1',
#   'sharpe': 0.1341,
#   'stddev': 0.0853,
#   'worst_year': -0.2207},
#  {'best_year': 0.2744,
#   'cagr': 0.0403,
#   'final_balance': 31420.47,
#   'initial_balance': 10000.0,
#   'mdd': -0.2079,
#   'mean_annual': 0.0423,
#   'name': 'SPY_simulation_3:2_4to7ex0',
#   'sharpe': 0.3801,
#   'stddev': 0.098,
#   'worst_year': -0.1394},
#  {'best_year': 0.2827,
#   'cagr': 0.0413,
#   'final_balance': 32380.07,
#   'initial_balance': 10000.0,
#   'mdd': -0.1985,
#   'mean_annual': 0.0431,
#   'name': 'SPY_simulation_3:2_4to7ex1',
#   'sharpe': 0.4555,
#   'stddev': 0.0837,
#   'worst_year': -0.1546},
#  {'best_year': 0.2711,
#   'cagr': 0.0535,
#   'final_balance': 45313.05,
#   'initial_balance': 10000.0,
#   'mdd': -0.2649,
#   'mean_annual': 0.0553,
#   'name': 'SPY_simulation_3:3_2to5ex0',
#   'sharpe': 0.481,
#   'stddev': 0.1046,
#   'worst_year': -0.194},
#  {'best_year': 0.2715,
#   'cagr': 0.0383,
#   'final_balance': 29714.22,
#   'initial_balance': 10000.0,
#   'mdd': -0.1979,
#   'mean_annual': 0.0399,
#   'name': 'SPY_simulation_3:3_2to5ex1',
#   'sharpe': 0.3827,
#   'stddev': 0.0913,
#   'worst_year': -0.161},
#  {'best_year': 0.1499,
#   'cagr': 0.0289,
#   'final_balance': 22815.66,
#   'initial_balance': 10000.0,
#   'mdd': -0.248,
#   'mean_annual': 0.0293,
#   'name': 'SPY_simulation_3:3_2to5ex2',
#   'sharpe': 0.3832,
#   'stddev': 0.0633,
#   'worst_year': -0.1436},
#  {'best_year': 0.2264,
#   'cagr': 0.047,
#   'final_balance': 37857.21,
#   'initial_balance': 10000.0,
#   'mdd': -0.2757,
#   'mean_annual': 0.0475,
#   'name': 'SPY_simulation_3:3_3to6ex0',
#   'sharpe': 0.4974,
#   'stddev': 0.0854,
#   'worst_year': -0.1479},
#  {'best_year': 0.2674,
#   'cagr': 0.0409,
#   'final_balance': 31963.4,
#   'initial_balance': 10000.0,
#   'mdd': -0.2847,
#   'mean_annual': 0.0427,
#   'name': 'SPY_simulation_3:3_3to6ex1',
#   'sharpe': 0.3772,
#   'stddev': 0.0999,
#   'worst_year': -0.1475},
#  {'best_year': 0.2863,
#   'cagr': 0.0299,
#   'final_balance': 23468.91,
#   'initial_balance': 10000.0,
#   'mdd': -0.3012,
#   'mean_annual': 0.0327,
#   'name': 'SPY_simulation_3:3_3to6ex2',
#   'sharpe': 0.2901,
#   'stddev': 0.0956,
#   'worst_year': -0.1283},
#  {'best_year': 0.2736,
#   'cagr': 0.0514,
#   'final_balance': 42766.73,
#   'initial_balance': 10000.0,
#   'mdd': -0.2237,
#   'mean_annual': 0.0532,
#   'name': 'SPY_simulation_3:3_4to7ex0',
#   'sharpe': 0.5004,
#   'stddev': 0.0964,
#   'worst_year': -0.1021},
#  {'best_year': 0.2112,
#   'cagr': 0.0409,
#   'final_balance': 31996.66,
#   'initial_balance': 10000.0,
#   'mdd': -0.27,
#   'mean_annual': 0.0423,
#   'name': 'SPY_simulation_3:3_4to7ex1',
#   'sharpe': 0.4874,
#   'stddev': 0.0765,
#   'worst_year': -0.1216},
#  {'best_year': 0.2085,
#   'cagr': 0.0214,
#   'final_balance': 18470.62,
#   'initial_balance': 10000.0,
#   'mdd': -0.2682,
#   'mean_annual': 0.0235,
#   'name': 'SPY_simulation_3:3_4to7ex2',
#   'sharpe': 0.2269,
#   'stddev': 0.0814,
#   'worst_year': -0.1642},
#  {'best_year': 0.2852,
#   'cagr': 0.0397,
#   'final_balance': 30947.8,
#   'initial_balance': 10000.0,
#   'mdd': -0.205,
#   'mean_annual': 0.0414,
#   'name': 'SPY_simulation_3:4_2to5ex0',
#   'sharpe': 0.3644,
#   'stddev': 0.0998,
#   'worst_year': -0.0939},
#  {'best_year': 0.2716,
#   'cagr': 0.0436,
#   'final_balance': 34432.3,
#   'initial_balance': 10000.0,
#   'mdd': -0.2031,
#   'mean_annual': 0.0447,
#   'name': 'SPY_simulation_3:4_2to5ex1',
#   'sharpe': 0.4515,
#   'stddev': 0.0879,
#   'worst_year': -0.0862},
#  {'best_year': 0.2451,
#   'cagr': 0.0399,
#   'final_balance': 31074.68,
#   'initial_balance': 10000.0,
#   'mdd': -0.172,
#   'mean_annual': 0.0419,
#   'name': 'SPY_simulation_3:4_2to5ex2',
#   'sharpe': 0.432,
#   'stddev': 0.0855,
#   'worst_year': -0.1287},
#  {'best_year': 0.2719,
#   'cagr': 0.0585,
#   'final_balance': 52053.27,
#   'initial_balance': 10000.0,
#   'mdd': -0.2669,
#   'mean_annual': 0.0592,
#   'name': 'SPY_simulation_3:4_3to6ex0',
#   'sharpe': 0.5935,
#   'stddev': 0.0914,
#   'worst_year': -0.1545},
#  {'best_year': 0.2708,
#   'cagr': 0.0402,
#   'final_balance': 31390.76,
#   'initial_balance': 10000.0,
#   'mdd': -0.2799,
#   'mean_annual': 0.0416,
#   'name': 'SPY_simulation_3:4_3to6ex1',
#   'sharpe': 0.3656,
#   'stddev': 0.1001,
#   'worst_year': -0.1283},
#  {'best_year': 0.2712,
#   'cagr': 0.0356,
#   'final_balance': 27585.1,
#   'initial_balance': 10000.0,
#   'mdd': -0.271,
#   'mean_annual': 0.0382,
#   'name': 'SPY_simulation_3:4_3to6ex2',
#   'sharpe': 0.3287,
#   'stddev': 0.1012,
#   'worst_year': -0.182},
#  {'best_year': 0.2919,
#   'cagr': 0.0606,
#   'final_balance': 55132.13,
#   'initial_balance': 10000.0,
#   'mdd': -0.2083,
#   'mean_annual': 0.0634,
#   'name': 'SPY_simulation_3:4_4to7ex0',
#   'sharpe': 0.5721,
#   'stddev': 0.102,
#   'worst_year': -0.1273},
#  {'best_year': 0.1951,
#   'cagr': 0.0543,
#   'final_balance': 46384.1,
#   'initial_balance': 10000.0,
#   'mdd': -0.2552,
#   'mean_annual': 0.0562,
#   'name': 'SPY_simulation_3:4_4to7ex1',
#   'sharpe': 0.6029,
#   'stddev': 0.085,
#   'worst_year': -0.128},
#  {'best_year': 0.1945,
#   'cagr': 0.0429,
#   'final_balance': 33793.24,
#   'initial_balance': 10000.0,
#   'mdd': -0.2459,
#   'mean_annual': 0.0464,
#   'name': 'SPY_simulation_3:4_4to7ex2',
#   'sharpe': 0.4169,
#   'stddev': 0.0993,
#   'worst_year': -0.2349},
#  {'best_year': 0.3048,
#   'cagr': 0.0616,
#   'final_balance': 56552.82,
#   'initial_balance': 10000.0,
#   'mdd': -0.1388,
#   'mean_annual': 0.0631,
#   'name': 'SPY_simulation_3:6_2to5ex0',
#   'sharpe': 0.5655,
#   'stddev': 0.1028,
#   'worst_year': -0.1945},
#  {'best_year': 0.3036,
#   'cagr': 0.0637,
#   'final_balance': 59928.27,
#   'initial_balance': 10000.0,
#   'mdd': -0.1986,
#   'mean_annual': 0.0648,
#   'name': 'SPY_simulation_3:6_2to5ex1',
#   'sharpe': 0.6264,
#   'stddev': 0.0955,
#   'worst_year': -0.0441},
#  {'best_year': 0.3244,
#   'cagr': 0.0775,
#   'final_balance': 87146.32,
#   'initial_balance': 10000.0,
#   'mdd': -0.1991,
#   'mean_annual': 0.0802,
#   'name': 'SPY_simulation_3:6_2to5ex2',
#   'sharpe': 0.7693,
#   'stddev': 0.0977,
#   'worst_year': -0.0827},
#  {'best_year': 0.3122,
#   'cagr': 0.0525,
#   'final_balance': 44068.16,
#   'initial_balance': 10000.0,
#   'mdd': -0.2893,
#   'mean_annual': 0.0566,
#   'name': 'SPY_simulation_3:6_3to6ex0',
#   'sharpe': 0.4055,
#   'stddev': 0.1273,
#   'worst_year': -0.1352},
#  {'best_year': 0.3121,
#   'cagr': 0.048,
#   'final_balance': 38949.52,
#   'initial_balance': 10000.0,
#   'mdd': -0.2896,
#   'mean_annual': 0.0529,
#   'name': 'SPY_simulation_3:6_3to6ex1',
#   'sharpe': 0.3809,
#   'stddev': 0.1259,
#   'worst_year': -0.1357},
#  {'best_year': 0.3124,
#   'cagr': 0.0579,
#   'final_balance': 51111.51,
#   'initial_balance': 10000.0,
#   'mdd': -0.2714,
#   'mean_annual': 0.0622,
#   'name': 'SPY_simulation_3:6_3to6ex2',
#   'sharpe': 0.4885,
#   'stddev': 0.1171,
#   'worst_year': -0.1358},
#  {'best_year': 0.3036,
#   'cagr': 0.0573,
#   'final_balance': 50324.64,
#   'initial_balance': 10000.0,
#   'mdd': -0.1979,
#   'mean_annual': 0.0605,
#   'name': 'SPY_simulation_3:6_4to7ex0',
#   'sharpe': 0.5131,
#   'stddev': 0.1082,
#   'worst_year': -0.1546},
#  {'best_year': 0.2725,
#   'cagr': 0.0541,
#   'final_balance': 46059.75,
#   'initial_balance': 10000.0,
#   'mdd': -0.1977,
#   'mean_annual': 0.0564,
#   'name': 'SPY_simulation_3:6_4to7ex1',
#   'sharpe': 0.5786,
#   'stddev': 0.0889,
#   'worst_year': -0.1547},
#  {'best_year': 0.2723,
#   'cagr': 0.0432,
#   'final_balance': 34132.17,
#   'initial_balance': 10000.0,
#   'mdd': -0.2052,
#   'mean_annual': 0.0473,
#   'name': 'SPY_simulation_3:6_4to7ex2',
#   'sharpe': 0.4014,
#   'stddev': 0.1053,
#   'worst_year': -0.2348},
#  {'best_year': 0.3045,
#   'cagr': 0.0767,
#   'final_balance': 85231.36,
#   'initial_balance': 10000.0,
#   'mdd': -0.2315,
#   'mean_annual': 0.0792,
#   'name': 'SPY_simulation_3:12_2to5ex0',
#   'sharpe': 0.6785,
#   'stddev': 0.1094,
#   'worst_year': -0.1076},
#  {'best_year': 0.3045,
#   'cagr': 0.0833,
#   'final_balance': 101889.97,
#   'initial_balance': 10000.0,
#   'mdd': -0.1987,
#   'mean_annual': 0.0851,
#   'name': 'SPY_simulation_3:12_2to5ex1',
#   'sharpe': 0.7557,
#   'stddev': 0.106,
#   'worst_year': -0.1076},
#  {'best_year': 0.3045,
#   'cagr': 0.0791,
#   'final_balance': 90987.62,
#   'initial_balance': 10000.0,
#   'mdd': -0.1989,
#   'mean_annual': 0.0813,
#   'name': 'SPY_simulation_3:12_2to5ex2',
#   'sharpe': 0.7171,
#   'stddev': 0.1064,
#   'worst_year': -0.1076},
#  {'best_year': 0.3045,
#   'cagr': 0.069,
#   'final_balance': 69194.37,
#   'initial_balance': 10000.0,
#   'mdd': -0.2152,
#   'mean_annual': 0.072,
#   'name': 'SPY_simulation_3:12_3to6ex0',
#   'sharpe': 0.5731,
#   'stddev': 0.117,
#   'worst_year': -0.115},
#  {'best_year': 0.305,
#   'cagr': 0.0706,
#   'final_balance': 72335.0,
#   'initial_balance': 10000.0,
#   'mdd': -0.2011,
#   'mean_annual': 0.0738,
#   'name': 'SPY_simulation_3:12_3to6ex1',
#   'sharpe': 0.6409,
#   'stddev': 0.1074,
#   'worst_year': -0.1048},
#  {'best_year': 0.3047,
#   'cagr': 0.0735,
#   'final_balance': 78122.11,
#   'initial_balance': 10000.0,
#   'mdd': -0.215,
#   'mean_annual': 0.0761,
#   'name': 'SPY_simulation_3:12_3to6ex2',
#   'sharpe': 0.6718,
#   'stddev': 0.1059,
#   'worst_year': -0.115},
#  {'best_year': 0.3041,
#   'cagr': 0.0851,
#   'final_balance': 106939.26,
#   'initial_balance': 10000.0,
#   'mdd': -0.1991,
#   'mean_annual': 0.087,
#   'name': 'SPY_simulation_3:12_4to7ex0',
#   'sharpe': 0.7933,
#   'stddev': 0.1033,
#   'worst_year': -0.0669},
#  {'best_year': 0.3041,
#   'cagr': 0.0869,
#   'final_balance': 112035.88,
#   'initial_balance': 10000.0,
#   'mdd': -0.1989,
#   'mean_annual': 0.0886,
#   'name': 'SPY_simulation_3:12_4to7ex1',
#   'sharpe': 0.819,
#   'stddev': 0.1021,
#   'worst_year': -0.0668},
#  {'best_year': 0.3047,
#   'cagr': 0.0921,
#   'final_balance': 128819.99,
#   'initial_balance': 10000.0,
#   'mdd': -0.2017,
#   'mean_annual': 0.0931,
#   'name': 'SPY_simulation_3:12_4to7ex2',
#   'sharpe': 0.8573,
#   'stddev': 0.1028,
#   'worst_year': -0.1017},
#  {'best_year': 0.2069,
#   'cagr': 0.0292,
#   'final_balance': 23032.08,
#   'initial_balance': 10000.0,
#   'mdd': -0.0943,
#   'mean_annual': 0.0296,
#   'name': 'SPY_simulation_4:1_2to6ex0',
#   'sharpe': 0.394,
#   'stddev': 0.0625,
#   'worst_year': -0.0727},
#  {'best_year': 0.4008,
#   'cagr': 0.0291,
#   'final_balance': 22971.27,
#   'initial_balance': 10000.0,
#   'mdd': -0.2493,
#   'mean_annual': 0.0324,
#   'name': 'SPY_simulation_4:1_3to7ex0',
#   'sharpe': 0.2485,
#   'stddev': 0.1102,
#   'worst_year': -0.2551},
#  {'best_year': 0.2308,
#   'cagr': 0.0254,
#   'final_balance': 20700.52,
#   'initial_balance': 10000.0,
#   'mdd': -0.3133,
#   'mean_annual': 0.0268,
#   'name': 'SPY_simulation_4:1_4to8ex0',
#   'sharpe': 0.2282,
#   'stddev': 0.0954,
#   'worst_year': -0.1553},
#  {'best_year': 0.2722,
#   'cagr': 0.0466,
#   'final_balance': 37467.17,
#   'initial_balance': 10000.0,
#   'mdd': -0.11,
#   'mean_annual': 0.0485,
#   'name': 'SPY_simulation_4:1_5to9ex0',
#   'sharpe': 0.5222,
#   'stddev': 0.0832,
#   'worst_year': -0.0919},
#  {'best_year': 0.2727,
#   'cagr': 0.0595,
#   'final_balance': 53467.46,
#   'initial_balance': 10000.0,
#   'mdd': -0.0795,
#   'mean_annual': 0.0607,
#   'name': 'SPY_simulation_4:2_2to6ex0',
#   'sharpe': 0.6192,
#   'stddev': 0.09,
#   'worst_year': -0.0865},
#  {'best_year': 0.2715,
#   'cagr': 0.0442,
#   'final_balance': 35036.74,
#   'initial_balance': 10000.0,
#   'mdd': -0.0804,
#   'mean_annual': 0.0453,
#   'name': 'SPY_simulation_4:2_2to6ex1',
#   'sharpe': 0.5266,
#   'stddev': 0.0764,
#   'worst_year': -0.0499},
#  {'best_year': 0.1848,
#   'cagr': 0.049,
#   'final_balance': 40039.63,
#   'initial_balance': 10000.0,
#   'mdd': -0.1988,
#   'mean_annual': 0.0487,
#   'name': 'SPY_simulation_4:2_3to7ex0',
#   'sharpe': 0.589,
#   'stddev': 0.0741,
#   'worst_year': -0.0878},
#  {'best_year': 0.1502,
#   'cagr': 0.0256,
#   'final_balance': 20796.45,
#   'initial_balance': 10000.0,
#   'mdd': -0.1986,
#   'mean_annual': 0.0258,
#   'name': 'SPY_simulation_4:2_3to7ex1',
#   'sharpe': 0.3609,
#   'stddev': 0.0576,
#   'worst_year': -0.1161},
#  {'best_year': 0.2746,
#   'cagr': 0.0338,
#   'final_balance': 26195.87,
#   'initial_balance': 10000.0,
#   'mdd': -0.3556,
#   'mean_annual': 0.0353,
#   'name': 'SPY_simulation_4:2_4to8ex0',
#   'sharpe': 0.3082,
#   'stddev': 0.0983,
#   'worst_year': -0.1498},
#  {'best_year': 0.273,
#   'cagr': 0.0408,
#   'final_balance': 31847.59,
#   'initial_balance': 10000.0,
#   'mdd': -0.3519,
#   'mean_annual': 0.0432,
#   'name': 'SPY_simulation_4:2_4to8ex1',
#   'sharpe': 0.3812,
#   'stddev': 0.1002,
#   'worst_year': -0.2019},
#  {'best_year': 0.2023,
#   'cagr': 0.0208,
#   'final_balance': 18151.42,
#   'initial_balance': 10000.0,
#   'mdd': -0.3871,
#   'mean_annual': 0.0245,
#   'name': 'SPY_simulation_4:2_5to9ex0',
#   'sharpe': 0.1934,
#   'stddev': 0.101,
#   'worst_year': -0.2242},
#  {'best_year': 0.2328,
#   'cagr': 0.0114,
#   'final_balance': 13895.69,
#   'initial_balance': 10000.0,
#   'mdd': -0.5301,
#   'mean_annual': 0.0179,
#   'name': 'SPY_simulation_4:2_5to9ex1',
#   'sharpe': 0.1086,
#   'stddev': 0.1191,
#   'worst_year': -0.3535},
#  {'best_year': 0.2713,
#   'cagr': 0.0517,
#   'final_balance': 43142.78,
#   'initial_balance': 10000.0,
#   'mdd': -0.0789,
#   'mean_annual': 0.053,
#   'name': 'SPY_simulation_4:3_2to6ex0',
#   'sharpe': 0.5415,
#   'stddev': 0.0886,
#   'worst_year': -0.1363},
#  {'best_year': 0.259,
#   'cagr': 0.031,
#   'final_balance': 24223.81,
#   'initial_balance': 10000.0,
#   'mdd': -0.3737,
#   'mean_annual': 0.0356,
#   'name': 'SPY_simulation_4:3_2to6ex1',
#   'sharpe': 0.2841,
#   'stddev': 0.1076,
#   'worst_year': -0.3065},
#  {'best_year': 0.2555,
#   'cagr': 0.0185,
#   'final_balance': 17030.09,
#   'initial_balance': 10000.0,
#   'mdd': -0.4903,
#   'mean_annual': 0.0234,
#   'name': 'SPY_simulation_4:3_2to6ex2',
#   'sharpe': 0.1712,
#   'stddev': 0.1076,
#   'worst_year': -0.2935},
#  {'best_year': 0.2712,
#   'cagr': 0.0571,
#   'final_balance': 50096.37,
#   'initial_balance': 10000.0,
#   'mdd': -0.21,
#   'mean_annual': 0.0571,
#   'name': 'SPY_simulation_4:3_3to7ex0',
#   'sharpe': 0.6,
#   'stddev': 0.0869,
#   'worst_year': -0.0885},
#  {'best_year': 0.2842,
#   'cagr': 0.0544,
#   'final_balance': 46459.37,
#   'initial_balance': 10000.0,
#   'mdd': -0.1989,
#   'mean_annual': 0.0559,
#   'name': 'SPY_simulation_4:3_3to7ex1',
#   'sharpe': 0.5588,
#   'stddev': 0.0911,
#   'worst_year': -0.1168},
#  {'best_year': 0.2845,
#   'cagr': 0.0438,
#   'final_balance': 34663.65,
#   'initial_balance': 10000.0,
#   'mdd': -0.0759,
#   'mean_annual': 0.0451,
#   'name': 'SPY_simulation_4:3_3to7ex2',
#   'sharpe': 0.4968,
#   'stddev': 0.0808,
#   'worst_year': -0.0985},
#  {'best_year': 0.2729,
#   'cagr': 0.034,
#   'final_balance': 26376.22,
#   'initial_balance': 10000.0,
#   'mdd': -0.2904,
#   'mean_annual': 0.0368,
#   'name': 'SPY_simulation_4:3_4to8ex0',
#   'sharpe': 0.2917,
#   'stddev': 0.109,
#   'worst_year': -0.1567},
#  {'best_year': 0.1854,
#   'cagr': 0.0392,
#   'final_balance': 30480.76,
#   'initial_balance': 10000.0,
#   'mdd': -0.2908,
#   'mean_annual': 0.0399,
#   'name': 'SPY_simulation_4:3_4to8ex1',
#   'sharpe': 0.4062,
#   'stddev': 0.0859,
#   'worst_year': -0.1492},
#  {'best_year': 0.2,
#   'cagr': 0.0089,
#   'final_balance': 12929.49,
#   'initial_balance': 10000.0,
#   'mdd': -0.197,
#   'mean_annual': 0.0095,
#   'name': 'SPY_simulation_4:3_4to8ex2',
#   'sharpe': 0.0712,
#   'stddev': 0.0627,
#   'worst_year': -0.1366},
#  {'best_year': 0.2722,
#   'cagr': 0.0495,
#   'final_balance': 40552.74,
#   'initial_balance': 10000.0,
#   'mdd': -0.2835,
#   'mean_annual': 0.0537,
#   'name': 'SPY_simulation_4:3_5to9ex0',
#   'sharpe': 0.4452,
#   'stddev': 0.1093,
#   'worst_year': -0.1731},
#  {'best_year': 0.2715,
#   'cagr': 0.0395,
#   'final_balance': 30778.5,
#   'initial_balance': 10000.0,
#   'mdd': -0.2288,
#   'mean_annual': 0.0425,
#   'name': 'SPY_simulation_4:3_5to9ex1',
#   'sharpe': 0.392,
#   'stddev': 0.0957,
#   'worst_year': -0.1729},
#  {'best_year': 0.2707,
#   'cagr': 0.0466,
#   'final_balance': 37496.7,
#   'initial_balance': 10000.0,
#   'mdd': -0.2843,
#   'mean_annual': 0.0513,
#   'name': 'SPY_simulation_4:3_5to9ex2',
#   'sharpe': 0.4422,
#   'stddev': 0.1046,
#   'worst_year': -0.276},
#  {'best_year': 0.2725,
#   'cagr': 0.0668,
#   'final_balance': 65288.27,
#   'initial_balance': 10000.0,
#   'mdd': -0.0793,
#   'mean_annual': 0.0689,
#   'name': 'SPY_simulation_4:4_2to6ex0',
#   'sharpe': 0.6772,
#   'stddev': 0.0943,
#   'worst_year': -0.1093},
#  {'best_year': 0.2727,
#   'cagr': 0.0603,
#   'final_balance': 54609.26,
#   'initial_balance': 10000.0,
#   'mdd': -0.2476,
#   'mean_annual': 0.0649,
#   'name': 'SPY_simulation_4:4_2to6ex1',
#   'sharpe': 0.5315,
#   'stddev': 0.1127,
#   'worst_year': -0.2428},
#  {'best_year': 0.271,
#   'cagr': 0.0479,
#   'final_balance': 38796.93,
#   'initial_balance': 10000.0,
#   'mdd': -0.1288,
#   'mean_annual': 0.0515,
#   'name': 'SPY_simulation_4:4_2to6ex2',
#   'sharpe': 0.4596,
#   'stddev': 0.1012,
#   'worst_year': -0.2431},
#  {'best_year': 0.2725,
#   'cagr': 0.0387,
#   'final_balance': 30054.39,
#   'initial_balance': 10000.0,
#   'mdd': -0.1979,
#   'mean_annual': 0.0391,
#   'name': 'SPY_simulation_4:4_3to7ex0',
#   'sharpe': 0.3974,
#   'stddev': 0.0859,
#   'worst_year': -0.0863},
#  {'best_year': 0.2722,
#   'cagr': 0.036,
#   'final_balance': 27854.25,
#   'initial_balance': 10000.0,
#   'mdd': -0.1972,
#   'mean_annual': 0.0367,
#   'name': 'SPY_simulation_4:4_3to7ex1',
#   'sharpe': 0.3855,
#   'stddev': 0.0822,
#   'worst_year': -0.1146},
#  {'best_year': 0.4456,
#   'cagr': 0.0309,
#   'final_balance': 24192.32,
#   'initial_balance': 10000.0,
#   'mdd': -0.39,
#   'mean_annual': 0.0374,
#   'name': 'SPY_simulation_4:4_3to7ex2',
#   'sharpe': 0.2576,
#   'stddev': 0.1258,
#   'worst_year': -0.3565},
#  {'best_year': 0.3034,
#   'cagr': 0.0483,
#   'final_balance': 39240.93,
#   'initial_balance': 10000.0,
#   'mdd': -0.3561,
#   'mean_annual': 0.0502,
#   'name': 'SPY_simulation_4:4_4to8ex0',
#   'sharpe': 0.4294,
#   'stddev': 0.1052,
#   'worst_year': -0.1494},
#  {'best_year': 0.2719,
#   'cagr': 0.0449,
#   'final_balance': 35727.15,
#   'initial_balance': 10000.0,
#   'mdd': -0.3558,
#   'mean_annual': 0.0453,
#   'name': 'SPY_simulation_4:4_4to8ex1',
#   'sharpe': 0.4464,
#   'stddev': 0.0903,
#   'worst_year': -0.1492},
#  {'best_year': 0.3045,
#   'cagr': 0.0415,
#   'final_balance': 32552.8,
#   'initial_balance': 10000.0,
#   'mdd': -0.3133,
#   'mean_annual': 0.0433,
#   'name': 'SPY_simulation_4:4_4to8ex2',
#   'sharpe': 0.407,
#   'stddev': 0.0942,
#   'worst_year': -0.1373},
#  {'best_year': 0.2914,
#   'cagr': 0.0586,
#   'final_balance': 52092.65,
#   'initial_balance': 10000.0,
#   'mdd': -0.2238,
#   'mean_annual': 0.0635,
#   'name': 'SPY_simulation_4:4_5to9ex0',
#   'sharpe': 0.4982,
#   'stddev': 0.1174,
#   'worst_year': -0.1734},
#  {'best_year': 0.2918,
#   'cagr': 0.0514,
#   'final_balance': 42774.8,
#   'initial_balance': 10000.0,
#   'mdd': -0.1976,
#   'mean_annual': 0.055,
#   'name': 'SPY_simulation_4:4_5to9ex1',
#   'sharpe': 0.4731,
#   'stddev': 0.1057,
#   'worst_year': -0.1302},
#  {'best_year': 0.2806,
#   'cagr': 0.0514,
#   'final_balance': 42724.68,
#   'initial_balance': 10000.0,
#   'mdd': -0.1979,
#   'mean_annual': 0.0539,
#   'name': 'SPY_simulation_4:4_5to9ex2',
#   'sharpe': 0.5045,
#   'stddev': 0.097,
#   'worst_year': -0.1292},
#  {'best_year': 0.3042,
#   'cagr': 0.0745,
#   'final_balance': 80407.23,
#   'initial_balance': 10000.0,
#   'mdd': -0.2611,
#   'mean_annual': 0.0776,
#   'name': 'SPY_simulation_4:6_2to6ex0',
#   'sharpe': 0.6728,
#   'stddev': 0.108,
#   'worst_year': -0.0864},
#  {'best_year': 0.2726,
#   'cagr': 0.0759,
#   'final_balance': 83491.04,
#   'initial_balance': 10000.0,
#   'mdd': -0.2615,
#   'mean_annual': 0.0786,
#   'name': 'SPY_simulation_4:6_2to6ex1',
#   'sharpe': 0.7898,
#   'stddev': 0.0932,
#   'worst_year': -0.0814},
#  {'best_year': 0.2724,
#   'cagr': 0.0852,
#   'final_balance': 107015.31,
#   'initial_balance': 10000.0,
#   'mdd': -0.1299,
#   'mean_annual': 0.0872,
#   'name': 'SPY_simulation_4:6_2to6ex2',
#   'sharpe': 0.9352,
#   'stddev': 0.0879,
#   'worst_year': -0.0646},
#  {'best_year': 0.3129,
#   'cagr': 0.0735,
#   'final_balance': 78249.71,
#   'initial_balance': 10000.0,
#   'mdd': -0.1984,
#   'mean_annual': 0.0766,
#   'name': 'SPY_simulation_4:6_3to7ex0',
#   'sharpe': 0.6058,
#   'stddev': 0.1181,
#   'worst_year': -0.2039},
#  {'best_year': 0.3131,
#   'cagr': 0.0702,
#   'final_balance': 71451.32,
#   'initial_balance': 10000.0,
#   'mdd': -0.1985,
#   'mean_annual': 0.0743,
#   'name': 'SPY_simulation_4:6_3to7ex1',
#   'sharpe': 0.5654,
#   'stddev': 0.1226,
#   'worst_year': -0.204},
#  {'best_year': 0.3126,
#   'cagr': 0.0539,
#   'final_balance': 45806.39,
#   'initial_balance': 10000.0,
#   'mdd': -0.1983,
#   'mean_annual': 0.0603,
#   'name': 'SPY_simulation_4:6_3to7ex2',
#   'sharpe': 0.4372,
#   'stddev': 0.1264,
#   'worst_year': -0.2886},
#  {'best_year': 0.3045,
#   'cagr': 0.0458,
#   'final_balance': 36672.68,
#   'initial_balance': 10000.0,
#   'mdd': -0.2455,
#   'mean_annual': 0.0482,
#   'name': 'SPY_simulation_4:6_4to8ex0',
#   'sharpe': 0.3884,
#   'stddev': 0.1113,
#   'worst_year': -0.149},
#  {'best_year': 0.3035,
#   'cagr': 0.0541,
#   'final_balance': 46121.98,
#   'initial_balance': 10000.0,
#   'mdd': -0.2459,
#   'mean_annual': 0.0566,
#   'name': 'SPY_simulation_4:6_4to8ex1',
#   'sharpe': 0.5023,
#   'stddev': 0.1027,
#   'worst_year': -0.1484},
#  {'best_year': 0.3042,
#   'cagr': 0.0607,
#   'final_balance': 55269.94,
#   'initial_balance': 10000.0,
#   'mdd': -0.1991,
#   'mean_annual': 0.0635,
#   'name': 'SPY_simulation_4:6_4to8ex2',
#   'sharpe': 0.5714,
#   'stddev': 0.1025,
#   'worst_year': -0.1484},
#  {'best_year': 0.3045,
#   'cagr': 0.0577,
#   'final_balance': 50831.7,
#   'initial_balance': 10000.0,
#   'mdd': -0.1985,
#   'mean_annual': 0.0611,
#   'name': 'SPY_simulation_4:6_5to9ex0',
#   'sharpe': 0.5221,
#   'stddev': 0.1074,
#   'worst_year': -0.1203},
#  {'best_year': 0.2815,
#   'cagr': 0.0507,
#   'final_balance': 41956.91,
#   'initial_balance': 10000.0,
#   'mdd': -0.1977,
#   'mean_annual': 0.0541,
#   'name': 'SPY_simulation_4:6_5to9ex1',
#   'sharpe': 0.47,
#   'stddev': 0.1044,
#   'worst_year': -0.1303},
#  {'best_year': 0.2821,
#   'cagr': 0.057,
#   'final_balance': 49940.41,
#   'initial_balance': 10000.0,
#   'mdd': -0.1989,
#   'mean_annual': 0.061,
#   'name': 'SPY_simulation_4:6_5to9ex2',
#   'sharpe': 0.5711,
#   'stddev': 0.0981,
#   'worst_year': -0.1297},
#  {'best_year': 0.3084,
#   'cagr': 0.0898,
#   'final_balance': 121032.78,
#   'initial_balance': 10000.0,
#   'mdd': -0.1992,
#   'mean_annual': 0.0922,
#   'name': 'SPY_simulation_4:12_2to6ex0',
#   'sharpe': 0.7929,
#   'stddev': 0.11,
#   'worst_year': -0.0866},
#  {'best_year': 0.3042,
#   'cagr': 0.0854,
#   'final_balance': 107738.65,
#   'initial_balance': 10000.0,
#   'mdd': -0.1991,
#   'mean_annual': 0.0874,
#   'name': 'SPY_simulation_4:12_2to6ex1',
#   'sharpe': 0.7946,
#   'stddev': 0.1037,
#   'worst_year': -0.0866},
#  {'best_year': 0.3042,
#   'cagr': 0.0811,
#   'final_balance': 95915.22,
#   'initial_balance': 10000.0,
#   'mdd': -0.1985,
#   'mean_annual': 0.0833,
#   'name': 'SPY_simulation_4:12_2to6ex2',
#   'sharpe': 0.6887,
#   'stddev': 0.1136,
#   'worst_year': -0.1261},
#  {'best_year': 0.3077,
#   'cagr': 0.0798,
#   'final_balance': 92711.68,
#   'initial_balance': 10000.0,
#   'mdd': -0.1988,
#   'mean_annual': 0.0834,
#   'name': 'SPY_simulation_4:12_3to7ex0',
#   'sharpe': 0.6549,
#   'stddev': 0.1197,
#   'worst_year': -0.1076},
#  {'best_year': 0.3046,
#   'cagr': 0.087,
#   'final_balance': 112440.43,
#   'initial_balance': 10000.0,
#   'mdd': -0.1992,
#   'mean_annual': 0.0888,
#   'name': 'SPY_simulation_4:12_3to7ex1',
#   'sharpe': 0.7904,
#   'stddev': 0.106,
#   'worst_year': -0.1076},
#  {'best_year': 0.3047,
#   'cagr': 0.0798,
#   'final_balance': 92729.05,
#   'initial_balance': 10000.0,
#   'mdd': -0.1991,
#   'mean_annual': 0.0823,
#   'name': 'SPY_simulation_4:12_3to7ex2',
#   'sharpe': 0.7107,
#   'stddev': 0.1088,
#   'worst_year': -0.1076},
#  {'best_year': 0.3041,
#   'cagr': 0.0672,
#   'final_balance': 65950.94,
#   'initial_balance': 10000.0,
#   'mdd': -0.3143,
#   'mean_annual': 0.0693,
#   'name': 'SPY_simulation_4:12_4to8ex0',
#   'sharpe': 0.5914,
#   'stddev': 0.1088,
#   'worst_year': -0.1149},
#  {'best_year': 0.3076,
#   'cagr': 0.0754,
#   'final_balance': 82221.31,
#   'initial_balance': 10000.0,
#   'mdd': -0.1987,
#   'mean_annual': 0.0793,
#   'name': 'SPY_simulation_4:12_4to8ex1',
#   'sharpe': 0.641,
#   'stddev': 0.1159,
#   'worst_year': -0.1149},
#  {'best_year': 0.3042,
#   'cagr': 0.0745,
#   'final_balance': 80287.31,
#   'initial_balance': 10000.0,
#   'mdd': -0.315,
#   'mean_annual': 0.0775,
#   'name': 'SPY_simulation_4:12_4to8ex2',
#   'sharpe': 0.664,
#   'stddev': 0.1092,
#   'worst_year': -0.1568},
#  {'best_year': 0.3045,
#   'cagr': 0.0781,
#   'final_balance': 88613.77,
#   'initial_balance': 10000.0,
#   'mdd': -0.1986,
#   'mean_annual': 0.0814,
#   'name': 'SPY_simulation_4:12_5to9ex0',
#   'sharpe': 0.6666,
#   'stddev': 0.1146,
#   'worst_year': -0.115},
#  {'best_year': 0.3045,
#   'cagr': 0.0762,
#   'final_balance': 84115.51,
#   'initial_balance': 10000.0,
#   'mdd': -0.1997,
#   'mean_annual': 0.0784,
#   'name': 'SPY_simulation_4:12_5to9ex1',
#   'sharpe': 0.7366,
#   'stddev': 0.0996,
#   'worst_year': -0.1148},
#  {'best_year': 0.3045,
#   'cagr': 0.0877,
#   'final_balance': 114600.89,
#   'initial_balance': 10000.0,
#   'mdd': -0.1986,
#   'mean_annual': 0.0904,
#   'name': 'SPY_simulation_4:12_5to9ex2',
#   'sharpe': 0.783,
#   'stddev': 0.109,
#   'worst_year': -0.115},
#  {'best_year': 0.188,
#   'cagr': 0.008,
#   'final_balance': 12591.05,
#   'initial_balance': 10000.0,
#   'mdd': -0.3181,
#   'mean_annual': 0.0098,
#   'name': 'SPY_simulation_6:1_2to8ex0',
#   'sharpe': 0.0632,
#   'stddev': 0.0757,
#   'worst_year': -0.1386},
#  {'best_year': 0.4003,
#   'cagr': 0.0304,
#   'final_balance': 23860.69,
#   'initial_balance': 10000.0,
#   'mdd': -0.3257,
#   'mean_annual': 0.0351,
#   'name': 'SPY_simulation_6:1_3to9ex0',
#   'sharpe': 0.2694,
#   'stddev': 0.1117,
#   'worst_year': -0.2852},
#  {'best_year': 0.2507,
#   'cagr': 0.0326,
#   'final_balance': 25363.93,
#   'initial_balance': 10000.0,
#   'mdd': -0.3233,
#   'mean_annual': 0.0369,
#   'name': 'SPY_simulation_6:1_4to10ex0',
#   'sharpe': 0.3067,
#   'stddev': 0.104,
#   'worst_year': -0.2987},
#  {'best_year': 0.2845,
#   'cagr': 0.0612,
#   'final_balance': 56012.9,
#   'initial_balance': 10000.0,
#   'mdd': -0.2215,
#   'mean_annual': 0.0632,
#   'name': 'SPY_simulation_6:1_5to11ex0',
#   'sharpe': 0.5893,
#   'stddev': 0.0987,
#   'worst_year': -0.1249},
#  {'best_year': 0.1903,
#   'cagr': 0.0362,
#   'final_balance': 28028.65,
#   'initial_balance': 10000.0,
#   'mdd': -0.1979,
#   'mean_annual': 0.035,
#   'name': 'SPY_simulation_6:1_6to12ex0',
#   'sharpe': 0.4784,
#   'stddev': 0.0626,
#   'worst_year': -0.0812},
#  {'best_year': 0.2718,
#   'cagr': 0.0438,
#   'final_balance': 34693.95,
#   'initial_balance': 10000.0,
#   'mdd': -0.14,
#   'mean_annual': 0.0464,
#   'name': 'SPY_simulation_6:1_7to13ex0',
#   'sharpe': 0.4746,
#   'stddev': 0.0871,
#   'worst_year': -0.0667},
#  {'best_year': 0.2717,
#   'cagr': 0.0492,
#   'final_balance': 40212.66,
#   'initial_balance': 10000.0,
#   'mdd': -0.1402,
#   'mean_annual': 0.0516,
#   'name': 'SPY_simulation_6:2_2to8ex0',
#   'sharpe': 0.505,
#   'stddev': 0.0923,
#   'worst_year': -0.0865},
#  {'best_year': 0.2719,
#   'cagr': 0.045,
#   'final_balance': 35853.4,
#   'initial_balance': 10000.0,
#   'mdd': -0.1398,
#   'mean_annual': 0.0472,
#   'name': 'SPY_simulation_6:2_2to8ex1',
#   'sharpe': 0.5089,
#   'stddev': 0.083,
#   'worst_year': -0.0666},
#  {'best_year': 0.2028,
#   'cagr': 0.0235,
#   'final_balance': 19606.5,
#   'initial_balance': 10000.0,
#   'mdd': -0.287,
#   'mean_annual': 0.0258,
#   'name': 'SPY_simulation_6:2_3to9ex0',
#   'sharpe': 0.2393,
#   'stddev': 0.0868,
#   'worst_year': -0.1532},
#  {'best_year': 0.1982,
#   'cagr': -0.0035,
#   'final_balance': 9042.17,
#   'initial_balance': 10000.0,
#   'mdd': -0.5146,
#   'mean_annual': -0.0002,
#   'name': 'SPY_simulation_6:2_3to9ex1',
#   'sharpe': -0.0565,
#   'stddev': 0.0924,
#   'worst_year': -0.2201},
#  {'best_year': 0.2746,
#   'cagr': 0.0395,
#   'final_balance': 30730.13,
#   'initial_balance': 10000.0,
#   'mdd': -0.3726,
#   'mean_annual': 0.0435,
#   'name': 'SPY_simulation_6:2_4to10ex0',
#   'sharpe': 0.3462,
#   'stddev': 0.1112,
#   'worst_year': -0.338},
#  {'best_year': 0.2732,
#   'cagr': 0.0349,
#   'final_balance': 27072.76,
#   'initial_balance': 10000.0,
#   'mdd': -0.2866,
#   'mean_annual': 0.0367,
#   'name': 'SPY_simulation_6:2_4to10ex1',
#   'sharpe': 0.379,
#   'stddev': 0.0836,
#   'worst_year': -0.178},
#  {'best_year': 0.2851,
#   'cagr': 0.0439,
#   'final_balance': 34792.33,
#   'initial_balance': 10000.0,
#   'mdd': -0.3842,
#   'mean_annual': 0.0489,
#   'name': 'SPY_simulation_6:2_5to11ex0',
#   'sharpe': 0.3591,
#   'stddev': 0.1222,
#   'worst_year': -0.3555},
#  {'best_year': 0.2518,
#   'cagr': 0.0336,
#   'final_balance': 26056.65,
#   'initial_balance': 10000.0,
#   'mdd': -0.3709,
#   'mean_annual': 0.0387,
#   'name': 'SPY_simulation_6:2_5to11ex1',
#   'sharpe': 0.3095,
#   'stddev': 0.1087,
#   'worst_year': -0.3549},
#  {'best_year': 0.2722,
#   'cagr': 0.0523,
#   'final_balance': 43861.2,
#   'initial_balance': 10000.0,
#   'mdd': -0.3106,
#   'mean_annual': 0.0534,
#   'name': 'SPY_simulation_6:2_6to12ex0',
#   'sharpe': 0.5215,
#   'stddev': 0.0927,
#   'worst_year': -0.1399},
#  {'best_year': 0.3041,
#   'cagr': 0.0554,
#   'final_balance': 47734.85,
#   'initial_balance': 10000.0,
#   'mdd': -0.3109,
#   'mean_annual': 0.0582,
#   'name': 'SPY_simulation_6:2_6to12ex1',
#   'sharpe': 0.4966,
#   'stddev': 0.1071,
#   'worst_year': -0.1396},
#  {'best_year': 0.272,
#   'cagr': 0.0483,
#   'final_balance': 39271.15,
#   'initial_balance': 10000.0,
#   'mdd': -0.1977,
#   'mean_annual': 0.0492,
#   'name': 'SPY_simulation_6:2_7to13ex0',
#   'sharpe': 0.5721,
#   'stddev': 0.0772,
#   'worst_year': -0.0668},
#  {'best_year': 0.1925,
#   'cagr': 0.0427,
#   'final_balance': 33657.11,
#   'initial_balance': 10000.0,
#   'mdd': -0.1977,
#   'mean_annual': 0.0431,
#   'name': 'SPY_simulation_6:2_7to13ex1',
#   'sharpe': 0.5734,
#   'stddev': 0.0664,
#   'worst_year': -0.0353},
#  {'best_year': 0.2725,
#   'cagr': 0.0332,
#   'final_balance': 25814.47,
#   'initial_balance': 10000.0,
#   'mdd': -0.2726,
#   'mean_annual': 0.0358,
#   'name': 'SPY_simulation_6:3_2to8ex0',
#   'sharpe': 0.3271,
#   'stddev': 0.0943,
#   'worst_year': -0.1378},
#  {'best_year': 0.272,
#   'cagr': 0.056,
#   'final_balance': 48538.17,
#   'initial_balance': 10000.0,
#   'mdd': -0.1989,
#   'mean_annual': 0.0572,
#   'name': 'SPY_simulation_6:3_2to8ex1',
#   'sharpe': 0.6382,
#   'stddev': 0.0817,
#   'worst_year': -0.0665},
#  {'best_year': 0.1865,
#   'cagr': 0.0231,
#   'final_balance': 19390.83,
#   'initial_balance': 10000.0,
#   'mdd': -0.1981,
#   'mean_annual': 0.0236,
#   'name': 'SPY_simulation_6:3_2to8ex2',
#   'sharpe': 0.29,
#   'stddev': 0.0641,
#   'worst_year': -0.0813},
#  {'best_year': 0.2721,
#   'cagr': 0.0513,
#   'final_balance': 42686.64,
#   'initial_balance': 10000.0,
#   'mdd': -0.197,
#   'mean_annual': 0.054,
#   'name': 'SPY_simulation_6:3_3to9ex0',
#   'sharpe': 0.515,
#   'stddev': 0.0952,
#   'worst_year': -0.1549},
#  {'best_year': 0.2789,
#   'cagr': 0.0516,
#   'final_balance': 42963.72,
#   'initial_balance': 10000.0,
#   'mdd': -0.2245,
#   'mean_annual': 0.0551,
#   'name': 'SPY_simulation_6:3_3to9ex1',
#   'sharpe': 0.4794,
#   'stddev': 0.1044,
#   'worst_year': -0.1064},
#  {'best_year': 0.2863,
#   'cagr': 0.0479,
#   'final_balance': 38870.06,
#   'initial_balance': 10000.0,
#   'mdd': -0.225,
#   'mean_annual': 0.0512,
#   'name': 'SPY_simulation_6:3_3to9ex2',
#   'sharpe': 0.4857,
#   'stddev': 0.0951,
#   'worst_year': -0.1069},
#  {'best_year': 0.2745,
#   'cagr': 0.0473,
#   'final_balance': 38205.23,
#   'initial_balance': 10000.0,
#   'mdd': -0.1979,
#   'mean_annual': 0.0484,
#   'name': 'SPY_simulation_6:3_4to10ex0',
#   'sharpe': 0.4922,
#   'stddev': 0.0882,
#   'worst_year': -0.1015},
#  {'best_year': 0.2304,
#   'cagr': 0.0402,
#   'final_balance': 31375.67,
#   'initial_balance': 10000.0,
#   'mdd': -0.1323,
#   'mean_annual': 0.0415,
#   'name': 'SPY_simulation_6:3_4to10ex1',
#   'sharpe': 0.4754,
#   'stddev': 0.0768,
#   'worst_year': -0.0871},
#  {'best_year': 0.2316,
#   'cagr': 0.0234,
#   'final_balance': 19559.75,
#   'initial_balance': 10000.0,
#   'mdd': -0.2933,
#   'mean_annual': 0.025,
#   'name': 'SPY_simulation_6:3_4to10ex2',
#   'sharpe': 0.263,
#   'stddev': 0.0759,
#   'worst_year': -0.0822},
#  {'best_year': 0.3033,
#   'cagr': 0.0647,
#   'final_balance': 61534.28,
#   'initial_balance': 10000.0,
#   'mdd': -0.3866,
#   'mean_annual': 0.0696,
#   'name': 'SPY_simulation_6:3_5to11ex0',
#   'sharpe': 0.5069,
#   'stddev': 0.1275,
#   'worst_year': -0.358},
#  {'best_year': 0.2723,
#   'cagr': 0.0382,
#   'final_balance': 29622.89,
#   'initial_balance': 10000.0,
#   'mdd': -0.4202,
#   'mean_annual': 0.043,
#   'name': 'SPY_simulation_6:3_5to11ex1',
#   'sharpe': 0.3362,
#   'stddev': 0.1131,
#   'worst_year': -0.3843},
#  {'best_year': 0.2709,
#   'cagr': 0.0309,
#   'final_balance': 24203.77,
#   'initial_balance': 10000.0,
#   'mdd': -0.3358,
#   'mean_annual': 0.0322,
#   'name': 'SPY_simulation_6:3_5to11ex2',
#   'sharpe': 0.346,
#   'stddev': 0.0787,
#   'worst_year': -0.1229},
#  {'best_year': 0.3031,
#   'cagr': 0.0603,
#   'final_balance': 54641.69,
#   'initial_balance': 10000.0,
#   'mdd': -0.2431,
#   'mean_annual': 0.0625,
#   'name': 'SPY_simulation_6:3_6to12ex0',
#   'sharpe': 0.5462,
#   'stddev': 0.1052,
#   'worst_year': -0.1399},
#  {'best_year': 0.3031,
#   'cagr': 0.0398,
#   'final_balance': 30969.92,
#   'initial_balance': 10000.0,
#   'mdd': -0.311,
#   'mean_annual': 0.0442,
#   'name': 'SPY_simulation_6:3_6to12ex1',
#   'sharpe': 0.3224,
#   'stddev': 0.1215,
#   'worst_year': -0.293},
#  {'best_year': 0.2512,
#   'cagr': 0.0418,
#   'final_balance': 32754.46,
#   'initial_balance': 10000.0,
#   'mdd': -0.1982,
#   'mean_annual': 0.0458,
#   'name': 'SPY_simulation_6:3_6to12ex2',
#   'sharpe': 0.3967,
#   'stddev': 0.1028,
#   'worst_year': -0.2947},
#  {'best_year': 0.237,
#   'cagr': 0.0482,
#   'final_balance': 39217.6,
#   'initial_balance': 10000.0,
#   'mdd': -0.2551,
#   'mean_annual': 0.0524,
#   'name': 'SPY_simulation_6:3_7to13ex0',
#   'sharpe': 0.5079,
#   'stddev': 0.0933,
#   'worst_year': -0.1942},
#  {'best_year': 0.2337,
#   'cagr': 0.0463,
#   'final_balance': 37202.95,
#   'initial_balance': 10000.0,
#   'mdd': -0.2539,
#   'mean_annual': 0.0491,
#   'name': 'SPY_simulation_6:3_7to13ex1',
#   'sharpe': 0.5266,
#   'stddev': 0.0838,
#   'worst_year': -0.1933},
#  {'best_year': 0.2908,
#   'cagr': 0.0503,
#   'final_balance': 41488.6,
#   'initial_balance': 10000.0,
#   'mdd': -0.2542,
#   'mean_annual': 0.0547,
#   'name': 'SPY_simulation_6:3_7to13ex2',
#   'sharpe': 0.4955,
#   'stddev': 0.1004,
#   'worst_year': -0.1944},
#  {'best_year': 0.2726,
#   'cagr': 0.043,
#   'final_balance': 33929.11,
#   'initial_balance': 10000.0,
#   'mdd': -0.2625,
#   'mean_annual': 0.0462,
#   'name': 'SPY_simulation_6:4_2to8ex0',
#   'sharpe': 0.4189,
#   'stddev': 0.0983,
#   'worst_year': -0.1733},
#  {'best_year': 0.262,
#   'cagr': 0.0452,
#   'final_balance': 36052.06,
#   'initial_balance': 10000.0,
#   'mdd': -0.2623,
#   'mean_annual': 0.0495,
#   'name': 'SPY_simulation_6:4_2to8ex1',
#   'sharpe': 0.4639,
#   'stddev': 0.096,
#   'worst_year': -0.1731},
#  {'best_year': 0.2612,
#   'cagr': 0.0422,
#   'final_balance': 33114.64,
#   'initial_balance': 10000.0,
#   'mdd': -0.1656,
#   'mean_annual': 0.0456,
#   'name': 'SPY_simulation_6:4_2to8ex2',
#   'sharpe': 0.4401,
#   'stddev': 0.0922,
#   'worst_year': -0.173},
#  {'best_year': 0.3061,
#   'cagr': 0.0433,
#   'final_balance': 34192.02,
#   'initial_balance': 10000.0,
#   'mdd': -0.2178,
#   'mean_annual': 0.0468,
#   'name': 'SPY_simulation_6:4_3to9ex0',
#   'sharpe': 0.398,
#   'stddev': 0.1051,
#   'worst_year': -0.1544},
#  {'best_year': 0.2721,
#   'cagr': 0.0256,
#   'final_balance': 20830.92,
#   'initial_balance': 10000.0,
#   'mdd': -0.2182,
#   'mean_annual': 0.0288,
#   'name': 'SPY_simulation_6:4_3to9ex1',
#   'sharpe': 0.2383,
#   'stddev': 0.0998,
#   'worst_year': -0.1459},
#  {'best_year': 0.2727,
#   'cagr': 0.0498,
#   'final_balance': 40945.1,
#   'initial_balance': 10000.0,
#   'mdd': -0.198,
#   'mean_annual': 0.0514,
#   'name': 'SPY_simulation_6:4_3to9ex2',
#   'sharpe': 0.5396,
#   'stddev': 0.0859,
#   'worst_year': -0.1069},
#  {'best_year': 0.3443,
#   'cagr': 0.0741,
# ...
#   'initial_balance': 10000.0,
#   'mdd': -0.199,
#   'mean_annual': 0.0642,
#   'name': 'SPY_simulation_12:6_4to16ex2',
#   'sharpe': 0.5117,
#   'stddev': 0.1157,
#   'worst_year': -0.182},
#  {'best_year': 0.3045,
#   'cagr': 0.0713,
#   'final_balance': 73785.78,
#   'initial_balance': 10000.0,
#   'mdd': -0.1401,
#   'mean_annual': 0.0748,
#   'name': 'SPY_simulation_12:6_5to17ex0',
#   'sharpe': 0.6368,
#   'stddev': 0.1096,
#   'worst_year': -0.0695},
#  {'best_year': 0.3045,
#   'cagr': 0.0721,
#   'final_balance': 75279.08,
#   'initial_balance': 10000.0,
#   'mdd': -0.1991,
#   'mean_annual': 0.0741,
#   'name': 'SPY_simulation_12:6_5to17ex1',
#   'sharpe': 0.6866,
#   'stddev': 0.1007,
#   'worst_year': -0.0594},
#  {'best_year': 0.2725,
#   'cagr': 0.0551,
#   'final_balance': 47360.46,
#   'initial_balance': 10000.0,
#   'mdd': -0.1988,
#   'mean_annual': 0.0559,
#   'name': 'SPY_simulation_12:6_5to17ex2',
#   'sharpe': 0.5668,
#   'stddev': 0.0898,
#   'worst_year': -0.1148},
#  {'best_year': 0.3041,
#   'cagr': 0.0679,
#   'final_balance': 67285.43,
#   'initial_balance': 10000.0,
#   'mdd': -0.1986,
#   'mean_annual': 0.071,
#   'name': 'SPY_simulation_12:6_6to18ex0',
#   'sharpe': 0.5854,
#   'stddev': 0.1128,
#   'worst_year': -0.126},
#  {'best_year': 0.3041,
#   'cagr': 0.0679,
#   'final_balance': 67285.43,
#   'initial_balance': 10000.0,
#   'mdd': -0.1986,
#   'mean_annual': 0.071,
#   'name': 'SPY_simulation_12:6_6to18ex1',
#   'sharpe': 0.5854,
#   'stddev': 0.1128,
#   'worst_year': -0.126},
#  {'best_year': 0.3041,
#   'cagr': 0.0775,
#   'final_balance': 87022.99,
#   'initial_balance': 10000.0,
#   'mdd': -0.1988,
#   'mean_annual': 0.0799,
#   'name': 'SPY_simulation_12:6_6to18ex2',
#   'sharpe': 0.7022,
#   'stddev': 0.1067,
#   'worst_year': -0.1264},
#  {'best_year': 0.2718,
#   'cagr': 0.0718,
#   'final_balance': 74773.33,
#   'initial_balance': 10000.0,
#   'mdd': -0.1988,
#   'mean_annual': 0.0722,
#   'name': 'SPY_simulation_12:6_7to19ex0',
#   'sharpe': 0.8451,
#   'stddev': 0.0795,
#   'worst_year': -0.0121},
#  {'best_year': 0.3049,
#   'cagr': 0.0714,
#   'final_balance': 73874.55,
#   'initial_balance': 10000.0,
#   'mdd': -0.199,
#   'mean_annual': 0.0733,
#   'name': 'SPY_simulation_12:6_7to19ex1',
#   'sharpe': 0.6882,
#   'stddev': 0.0993,
#   'worst_year': -0.0354},
#  {'best_year': 0.2719,
#   'cagr': 0.0424,
#   'final_balance': 33375.81,
#   'initial_balance': 10000.0,
#   'mdd': -0.5204,
#   'mean_annual': 0.0479,
#   'name': 'SPY_simulation_12:6_7to19ex2',
#   'sharpe': 0.3652,
#   'stddev': 0.1175,
#   'worst_year': -0.3829},
#  {'best_year': 0.3071,
#   'cagr': 0.0372,
#   'final_balance': 28824.4,
#   'initial_balance': 10000.0,
#   'mdd': -0.3097,
#   'mean_annual': 0.0404,
#   'name': 'SPY_simulation_12:6_8to20ex0',
#   'sharpe': 0.3378,
#   'stddev': 0.1047,
#   'worst_year': -0.135},
#  {'best_year': 0.3079,
#   'cagr': 0.0641,
#   'final_balance': 60577.82,
#   'initial_balance': 10000.0,
#   'mdd': -0.1989,
#   'mean_annual': 0.0668,
#   'name': 'SPY_simulation_12:6_8to20ex1',
#   'sharpe': 0.6223,
#   'stddev': 0.0993,
#   'worst_year': -0.0668},
#  {'best_year': 0.3047,
#   'cagr': 0.0652,
#   'final_balance': 62516.82,
#   'initial_balance': 10000.0,
#   'mdd': -0.1979,
#   'mean_annual': 0.0677,
#   'name': 'SPY_simulation_12:6_8to20ex2',
#   'sharpe': 0.6375,
#   'stddev': 0.0984,
#   'worst_year': -0.121},
#  {'best_year': 0.3071,
#   'cagr': 0.0537,
#   'final_balance': 45610.02,
#   'initial_balance': 10000.0,
#   'mdd': -0.1985,
#   'mean_annual': 0.0579,
#   'name': 'SPY_simulation_12:6_9to21ex0',
#   'sharpe': 0.4641,
#   'stddev': 0.114,
#   'worst_year': -0.2069},
#  {'best_year': 0.3444,
#   'cagr': 0.0508,
#   'final_balance': 42066.7,
#   'initial_balance': 10000.0,
#   'mdd': -0.1991,
#   'mean_annual': 0.0552,
#   'name': 'SPY_simulation_12:6_9to21ex1',
#   'sharpe': 0.4357,
#   'stddev': 0.1152,
#   'worst_year': -0.2079},
#  {'best_year': 0.3079,
#   'cagr': 0.0421,
#   'final_balance': 33077.04,
#   'initial_balance': 10000.0,
#   'mdd': -0.1989,
#   'mean_annual': 0.0467,
#   'name': 'SPY_simulation_12:6_9to21ex2',
#   'sharpe': 0.4205,
#   'stddev': 0.099,
#   'worst_year': -0.2894},
#  {'best_year': 0.3443,
#   'cagr': 0.0663,
#   'final_balance': 64376.12,
#   'initial_balance': 10000.0,
#   'mdd': -0.3749,
#   'mean_annual': 0.0732,
#   'name': 'SPY_simulation_12:6_10to22ex0',
#   'sharpe': 0.504,
#   'stddev': 0.1353,
#   'worst_year': -0.3382},
#  {'best_year': 0.2719,
#   'cagr': 0.0614,
#   'final_balance': 56249.15,
#   'initial_balance': 10000.0,
#   'mdd': -0.1402,
#   'mean_annual': 0.0628,
#   'name': 'SPY_simulation_12:6_10to22ex1',
#   'sharpe': 0.734,
#   'stddev': 0.0788,
#   'worst_year': -0.0668},
#  {'best_year': 0.3443,
#   'cagr': 0.0689,
#   'final_balance': 68984.37,
#   'initial_balance': 10000.0,
#   'mdd': -0.1401,
#   'mean_annual': 0.0714,
#   'name': 'SPY_simulation_12:6_10to22ex2',
#   'sharpe': 0.6967,
#   'stddev': 0.0953,
#   'worst_year': -0.0668},
#  {'best_year': 0.3048,
#   'cagr': 0.0771,
#   'final_balance': 86138.39,
#   'initial_balance': 10000.0,
#   'mdd': -0.2216,
#   'mean_annual': 0.0781,
#   'name': 'SPY_simulation_12:6_11to23ex0',
#   'sharpe': 0.734,
#   'stddev': 0.0996,
#   'worst_year': -0.1077},
#  {'best_year': 0.3048,
#   'cagr': 0.0639,
#   'final_balance': 60257.4,
#   'initial_balance': 10000.0,
#   'mdd': -0.2217,
#   'mean_annual': 0.0649,
#   'name': 'SPY_simulation_12:6_11to23ex1',
#   'sharpe': 0.6404,
#   'stddev': 0.0935,
#   'worst_year': -0.1071},
#  {'best_year': 0.3065,
#   'cagr': 0.0601,
#   'final_balance': 54275.14,
#   'initial_balance': 10000.0,
#   'mdd': -0.1982,
#   'mean_annual': 0.0625,
#   'name': 'SPY_simulation_12:6_11to23ex2',
#   'sharpe': 0.6014,
#   'stddev': 0.0956,
#   'worst_year': -0.0665},
#  {'best_year': 0.304,
#   'cagr': 0.0678,
#   'final_balance': 67101.27,
#   'initial_balance': 10000.0,
#   'mdd': -0.3108,
#   'mean_annual': 0.0695,
#   'name': 'SPY_simulation_12:6_12to24ex0',
#   'sharpe': 0.61,
#   'stddev': 0.1057,
#   'worst_year': -0.1149},
#  {'best_year': 0.304,
#   'cagr': 0.0689,
#   'final_balance': 69099.38,
#   'initial_balance': 10000.0,
#   'mdd': -0.3114,
#   'mean_annual': 0.0708,
#   'name': 'SPY_simulation_12:6_12to24ex1',
#   'sharpe': 0.6673,
#   'stddev': 0.0987,
#   'worst_year': -0.0668},
#  {'best_year': 0.3445,
#   'cagr': 0.0654,
#   'final_balance': 62741.97,
#   'initial_balance': 10000.0,
#   'mdd': -0.3111,
#   'mean_annual': 0.0682,
#   'name': 'SPY_simulation_12:6_12to24ex2',
#   'sharpe': 0.5988,
#   'stddev': 0.1056,
#   'worst_year': -0.0668},
#  {'best_year': 0.305,
#   'cagr': 0.0582,
#   'final_balance': 51562.35,
#   'initial_balance': 10000.0,
#   'mdd': -0.2557,
#   'mean_annual': 0.0605,
#   'name': 'SPY_simulation_12:6_13to25ex0',
#   'sharpe': 0.5764,
#   'stddev': 0.0963,
#   'worst_year': -0.0668},
#  {'best_year': 0.305,
#   'cagr': 0.0527,
#   'final_balance': 44381.89,
#   'initial_balance': 10000.0,
#   'mdd': -0.255,
#   'mean_annual': 0.0555,
#   'name': 'SPY_simulation_12:6_13to25ex1',
#   'sharpe': 0.5286,
#   'stddev': 0.0955,
#   'worst_year': -0.1143},
#  {'best_year': 0.305,
#   'cagr': 0.0603,
#   'final_balance': 54578.74,
#   'initial_balance': 10000.0,
#   'mdd': -0.2556,
#   'mean_annual': 0.0637,
#   'name': 'SPY_simulation_12:6_13to25ex2',
#   'sharpe': 0.5891,
#   'stddev': 0.0996,
#   'worst_year': -0.0666},
#  {'best_year': 0.3069,
#   'cagr': 0.0717,
#   'final_balance': 74460.04,
#   'initial_balance': 10000.0,
#   'mdd': -0.1984,
#   'mean_annual': 0.0752,
#   'name': 'SPY_simulation_12:12_2to14ex0',
#   'sharpe': 0.6048,
#   'stddev': 0.116,
#   'worst_year': -0.1148},
#  {'best_year': 0.3036,
#   'cagr': 0.0657,
#   'final_balance': 63356.38,
#   'initial_balance': 10000.0,
#   'mdd': -0.1652,
#   'mean_annual': 0.0695,
#   'name': 'SPY_simulation_12:12_2to14ex1',
#   'sharpe': 0.5894,
#   'stddev': 0.1094,
#   'worst_year': -0.1148},
#  {'best_year': 0.3036,
#   'cagr': 0.0408,
#   'final_balance': 31873.32,
#   'initial_balance': 10000.0,
#   'mdd': -0.5556,
#   'mean_annual': 0.0496,
#   'name': 'SPY_simulation_12:12_2to14ex2',
#   'sharpe': 0.3175,
#   'stddev': 0.1405,
#   'worst_year': -0.3835},
#  {'best_year': 0.3073,
#   'cagr': 0.0614,
#   'final_balance': 56288.14,
#   'initial_balance': 10000.0,
#   'mdd': -0.1986,
#   'mean_annual': 0.0671,
#   'name': 'SPY_simulation_12:12_3to15ex0',
#   'sharpe': 0.476,
#   'stddev': 0.1304,
#   'worst_year': -0.2028},
#  {'best_year': 0.3449,
#   'cagr': 0.0817,
#   'final_balance': 97425.53,
#   'initial_balance': 10000.0,
#   'mdd': -0.1992,
#   'mean_annual': 0.0864,
#   'name': 'SPY_simulation_12:12_3to15ex1',
#   'sharpe': 0.6376,
#   'stddev': 0.1277,
#   'worst_year': -0.1159},
#  {'best_year': 0.3068,
#   'cagr': 0.0681,
#   'final_balance': 67582.26,
#   'initial_balance': 10000.0,
#   'mdd': -0.1984,
#   'mean_annual': 0.0719,
#   'name': 'SPY_simulation_12:12_3to15ex2',
#   'sharpe': 0.5996,
#   'stddev': 0.1116,
#   'worst_year': -0.1158},
#  {'best_year': 0.3082,
#   'cagr': 0.0674,
#   'final_balance': 66355.07,
#   'initial_balance': 10000.0,
#   'mdd': -0.1991,
#   'mean_annual': 0.0714,
#   'name': 'SPY_simulation_12:12_4to16ex0',
#   'sharpe': 0.5629,
#   'stddev': 0.118,
#   'worst_year': -0.1149},
#  {'best_year': 0.3082,
#   'cagr': 0.0674,
#   'final_balance': 66355.07,
#   'initial_balance': 10000.0,
#   'mdd': -0.1991,
#   'mean_annual': 0.0714,
#   'name': 'SPY_simulation_12:12_4to16ex1',
#   'sharpe': 0.5629,
#   'stddev': 0.118,
#   'worst_year': -0.1149},
#  {'best_year': 0.3441,
#   'cagr': 0.091,
#   'final_balance': 124994.88,
#   'initial_balance': 10000.0,
#   'mdd': -0.1989,
#   'mean_annual': 0.0946,
#   'name': 'SPY_simulation_12:12_4to16ex2',
#   'sharpe': 0.7684,
#   'stddev': 0.1166,
#   'worst_year': -0.0668},
#  {'best_year': 0.3045,
#   'cagr': 0.0705,
#   'final_balance': 72208.17,
#   'initial_balance': 10000.0,
#   'mdd': -0.1402,
#   'mean_annual': 0.0738,
#   'name': 'SPY_simulation_12:12_5to17ex0',
#   'sharpe': 0.6722,
#   'stddev': 0.1023,
#   'worst_year': -0.115},
#  {'best_year': 0.3075,
#   'cagr': 0.0799,
#   'final_balance': 92871.08,
#   'initial_balance': 10000.0,
#   'mdd': -0.1987,
#   'mean_annual': 0.0835,
#   'name': 'SPY_simulation_12:12_5to17ex1',
#   'sharpe': 0.6893,
#   'stddev': 0.1138,
#   'worst_year': -0.115},
#  {'best_year': 0.308,
#   'cagr': 0.0704,
#   'final_balance': 71909.97,
#   'initial_balance': 10000.0,
#   'mdd': -0.1989,
#   'mean_annual': 0.074,
#   'name': 'SPY_simulation_12:12_5to17ex2',
#   'sharpe': 0.6,
#   'stddev': 0.1151,
#   'worst_year': -0.115},
#  {'best_year': 0.3083,
#   'cagr': 0.0842,
#   'final_balance': 104314.22,
#   'initial_balance': 10000.0,
#   'mdd': -0.1991,
#   'mean_annual': 0.0882,
#   'name': 'SPY_simulation_12:12_6to18ex0',
#   'sharpe': 0.6853,
#   'stddev': 0.1215,
#   'worst_year': -0.1265},
#  {'best_year': 0.3041,
#   'cagr': 0.0825,
#   'final_balance': 99590.45,
#   'initial_balance': 10000.0,
#   'mdd': -0.1402,
#   'mean_annual': 0.086,
#   'name': 'SPY_simulation_12:12_6to18ex1',
#   'sharpe': 0.767,
#   'stddev': 0.1056,
#   'worst_year': -0.1264},
#  {'best_year': 0.3084,
#   'cagr': 0.0643,
#   'final_balance': 60904.57,
#   'initial_balance': 10000.0,
#   'mdd': -0.1992,
#   'mean_annual': 0.069,
#   'name': 'SPY_simulation_12:12_6to18ex2',
#   'sharpe': 0.5236,
#   'stddev': 0.1222,
#   'worst_year': -0.1261},
#  {'best_year': 0.3082,
#   'cagr': 0.0803,
#   'final_balance': 94023.74,
#   'initial_balance': 10000.0,
#   'mdd': -0.1991,
#   'mean_annual': 0.0842,
#   'name': 'SPY_simulation_12:12_7to19ex0',
#   'sharpe': 0.6606,
#   'stddev': 0.1199,
#   'worst_year': -0.134},
#  {'best_year': 0.3071,
#   'cagr': 0.0755,
#   'final_balance': 82606.4,
#   'initial_balance': 10000.0,
#   'mdd': -0.1985,
#   'mean_annual': 0.0795,
#   'name': 'SPY_simulation_12:12_7to19ex1',
#   'sharpe': 0.6304,
#   'stddev': 0.1181,
#   'worst_year': -0.134},
#  {'best_year': 0.3049,
#   'cagr': 0.0721,
#   'final_balance': 75276.58,
#   'initial_balance': 10000.0,
#   'mdd': -0.1398,
#   'mean_annual': 0.0757,
#   'name': 'SPY_simulation_12:12_7to19ex2',
#   'sharpe': 0.628,
#   'stddev': 0.1126,
#   'worst_year': -0.134},
#  {'best_year': 0.3047,
#   'cagr': 0.0741,
#   'final_balance': 79465.8,
#   'initial_balance': 10000.0,
#   'mdd': -0.1402,
#   'mean_annual': 0.0772,
#   'name': 'SPY_simulation_12:12_8to20ex0',
#   'sharpe': 0.6165,
#   'stddev': 0.1171,
#   'worst_year': -0.1351},
#  {'best_year': 0.308,
#   'cagr': 0.0797,
#   'final_balance': 92346.1,
#   'initial_balance': 10000.0,
#   'mdd': -0.199,
#   'mean_annual': 0.084,
#   'name': 'SPY_simulation_12:12_8to20ex1',
#   'sharpe': 0.6415,
#   'stddev': 0.1231,
#   'worst_year': -0.1351},
#  {'best_year': 0.3047,
#   'cagr': 0.0731,
#   'final_balance': 77327.15,
#   'initial_balance': 10000.0,
#   'mdd': -0.1402,
#   'mean_annual': 0.0769,
#   'name': 'SPY_simulation_12:12_8to20ex2',
#   'sharpe': 0.6171,
#   'stddev': 0.1165,
#   'worst_year': -0.1351},
#  {'best_year': 0.3084,
#   'cagr': 0.0599,
#   'final_balance': 54075.76,
#   'initial_balance': 10000.0,
#   'mdd': -0.3137,
#   'mean_annual': 0.0662,
#   'name': 'SPY_simulation_12:12_9to21ex0',
#   'sharpe': 0.4453,
#   'stddev': 0.1375,
#   'worst_year': -0.2083},
#  {'best_year': 0.3037,
#   'cagr': 0.0604,
#   'final_balance': 54770.28,
#   'initial_balance': 10000.0,
#   'mdd': -0.3129,
#   'mean_annual': 0.0651,
#   'name': 'SPY_simulation_12:12_9to21ex1',
#   'sharpe': 0.5034,
#   'stddev': 0.1193,
#   'worst_year': -0.2084},
#  {'best_year': 0.3077,
#   'cagr': 0.0683,
#   'final_balance': 67898.73,
#   'initial_balance': 10000.0,
#   'mdd': -0.1988,
#   'mean_annual': 0.0741,
#   'name': 'SPY_simulation_12:12_9to21ex2',
#   'sharpe': 0.5203,
#   'stddev': 0.1328,
#   'worst_year': -0.2083},
#  {'best_year': 0.3083,
#   'cagr': 0.08,
#   'final_balance': 93159.37,
#   'initial_balance': 10000.0,
#   'mdd': -0.1991,
#   'mean_annual': 0.0856,
#   'name': 'SPY_simulation_12:12_10to22ex0',
#   'sharpe': 0.6209,
#   'stddev': 0.1298,
#   'worst_year': -0.3387},
#  {'best_year': 0.3079,
#   'cagr': 0.0747,
#   'final_balance': 80771.77,
#   'initial_balance': 10000.0,
#   'mdd': -0.3755,
#   'mean_annual': 0.0803,
#   'name': 'SPY_simulation_12:12_10to22ex1',
#   'sharpe': 0.5799,
#   'stddev': 0.1299,
#   'worst_year': -0.3387},
#  {'best_year': 0.3068,
#   'cagr': 0.0679,
#   'final_balance': 67150.76,
#   'initial_balance': 10000.0,
#   'mdd': -0.1984,
#   'mean_annual': 0.0743,
#   'name': 'SPY_simulation_12:12_10to22ex2',
#   'sharpe': 0.4905,
#   'stddev': 0.1414,
#   'worst_year': -0.3391},
#  {'best_year': 0.3083,
#   'cagr': 0.0703,
#   'final_balance': 71690.82,
#   'initial_balance': 10000.0,
#   'mdd': -0.4518,
#   'mean_annual': 0.0775,
#   'name': 'SPY_simulation_12:12_11to23ex0',
#   'sharpe': 0.5212,
#   'stddev': 0.1391,
#   'worst_year': -0.3839},
#  {'best_year': 0.3048,
#   'cagr': 0.0612,
#   'final_balance': 56043.43,
#   'initial_balance': 10000.0,
#   'mdd': -0.4513,
#   'mean_annual': 0.0669,
#   'name': 'SPY_simulation_12:12_11to23ex1',
#   'sharpe': 0.4769,
#   'stddev': 0.1299,
#   'worst_year': -0.3835},
#  {'best_year': 0.3081,
#   'cagr': 0.0635,
#   'final_balance': 59696.79,
#   'initial_balance': 10000.0,
#   'mdd': -0.4518,
#   'mean_annual': 0.0708,
#   'name': 'SPY_simulation_12:12_11to23ex2',
#   'sharpe': 0.472,
#   'stddev': 0.1394,
#   'worst_year': -0.3839},
#  {'best_year': 0.304,
#   'cagr': 0.0455,
#   'final_balance': 36362.39,
#   'initial_balance': 10000.0,
#   'mdd': -0.459,
#   'mean_annual': 0.0517,
#   'name': 'SPY_simulation_12:12_12to24ex0',
#   'sharpe': 0.3498,
#   'stddev': 0.1334,
#   'worst_year': -0.3837},
#  {'best_year': 0.3084,
#   'cagr': 0.0581,
#   'final_balance': 51506.76,
#   'initial_balance': 10000.0,
#   'mdd': -0.459,
#   'mean_annual': 0.0664,
#   'name': 'SPY_simulation_12:12_12to24ex1',
#   'sharpe': 0.4358,
#   'stddev': 0.1409,
#   'worst_year': -0.3837},
#  {'best_year': 0.304,
#   'cagr': 0.0478,
#   'final_balance': 38730.94,
#   'initial_balance': 10000.0,
#   'mdd': -0.4588,
#   'mean_annual': 0.0548,
#   'name': 'SPY_simulation_12:12_12to24ex2',
#   'sharpe': 0.3724,
#   'stddev': 0.1338,
#   'worst_year': -0.3835},
#  {'best_year': 0.305,
#   'cagr': 0.0715,
#   'final_balance': 74131.64,
#   'initial_balance': 10000.0,
#   'mdd': -0.255,
#   'mean_annual': 0.0744,
#   'name': 'SPY_simulation_12:12_13to25ex0',
#   'sharpe': 0.6517,
#   'stddev': 0.1065,
#   'worst_year': -0.1151},
#  {'best_year': 0.305,
#   'cagr': 0.0726,
#   'final_balance': 76429.67,
#   'initial_balance': 10000.0,
#   'mdd': -0.2559,
#   'mean_annual': 0.0756,
#   'name': 'SPY_simulation_12:12_13to25ex1',
#   'sharpe': 0.6854,
#   'stddev': 0.103,
#   'worst_year': -0.1151},
#  {'best_year': 0.305,
#   'cagr': 0.0541,
#   'final_balance': 46098.9,
#   'initial_balance': 10000.0,
#   'mdd': -0.4841,
#   'mean_annual': 0.0616,
#   'name': 'SPY_simulation_12:12_13to25ex2',
#   'sharpe': 0.4257,
#   'stddev': 0.133,
#   'worst_year': -0.3832}]

# %% [markdown]
# # 결과 출력

# %% [markdown]
# ## csv / jpg 출력

# %%
statistics_df = pd.DataFrame(strategies)
print(statistics_df)
print(statistics_df.iloc[statistics_df['final_balance'].idxmax()])
# Out:
#                                name  initial_balance  ...  best_year     mdd
# 0                         Benchmark          9991.41  ...     0.3453 -0.5220
# 1        SPY_simulation_1:1_2to3ex0         10000.00  ...     0.2664 -0.2023
# 2        SPY_simulation_1:2_2to3ex0         10000.00  ...     0.2730 -0.1165
# 3        SPY_simulation_1:2_2to3ex1         10000.00  ...     0.2519 -0.3392
# 4        SPY_simulation_1:3_2to3ex0         10000.00  ...     0.2736 -0.1795
# ..                              ...              ...  ...        ...     ...
# 416  SPY_simulation_12:12_12to24ex1         10000.00  ...     0.3084 -0.4590
# 417  SPY_simulation_12:12_12to24ex2         10000.00  ...     0.3040 -0.4588
# 418  SPY_simulation_12:12_13to25ex0         10000.00  ...     0.3050 -0.2550
# 419  SPY_simulation_12:12_13to25ex1         10000.00  ...     0.3050 -0.2559
# 420  SPY_simulation_12:12_13to25ex2         10000.00  ...     0.3050 -0.4841
#
# [421 rows x 10 columns]
# name               SPY_simulation_6:12_4to10ex2
# initial_balance                           10000
# final_balance                            139479
# cagr                                     0.0951
# mean_annual                              0.0968
# stddev                                   0.1107
# sharpe                                   0.8291
# worst_year                              -0.1018
# best_year                                0.3084
# mdd                                     -0.1992
# Name: 231, dtype: object

# %%
statistics_df.to_csv(f'/content/drive/MyDrive/quant_projects/momentum_strategies/{current_date}_statistics.csv')

# %%
returns_df = pd.DataFrame({'Date': df['Date']})
for portfolio in returns:
  returns_df[portfolio['name']] = portfolio['df']
print(returns_df)
returns_df.to_csv(f'/content/drive/MyDrive/quant_projects/momentum_strategies/{current_date}_returns.csv')
# Out:
#            Date  ...  SPY_simulation_12:12_13to25ex2
# 0    1993-02-01  ...                    10000.000000
# 1    1993-03-01  ...                    10000.000000
# 2    1993-04-01  ...                    10000.000000
# 3    1993-05-01  ...                    10000.000000
# 4    1993-06-01  ...                    10000.000000
# ..          ...  ...                             ...
# 339  2021-05-01  ...                    45125.196506
# 340  2021-06-01  ...                    45983.335329
# 341  2021-07-01  ...                    47101.486613
# 342  2021-08-01  ...                    48497.835329
# 343  2021-09-01  ...                    46098.897148
#
# [344 rows x 422 columns]

# %%
chart = returns_df.plot.line(x='Date', grid=True, figsize=(40,25), xticks=np.arange(0, 346, 12), yticks=np.arange(0, 150000, 10000))
chart.tick_params(axis='x', rotation=90)
chart.figure.savefig(f'/content/drive/MyDrive/quant_projects/momentum_strategies/{current_date}_returns.jpg')
